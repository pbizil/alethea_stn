# %% [markdown]
# ## Modelagem - Apartamentos

# %% [markdown]
# Carga dos dados e pré processamento das variáveis para modelagem de preços de apartamentos.

# %%
import pandas as pd

data_apartamentos = pd.read_csv("data/html_apartamentos/data_apartamentos.csv")
data_apartamentos = data_apartamentos[["municipio", "area", "lat", "lng", "valor"]]

# %%
data_apartamentos = data_apartamentos.drop_duplicates()
data_apartamentos["municipio"] = data_apartamentos["municipio"].str.lower()
data_apartamentos["area"] = data_apartamentos["area"].str.replace("\n", "")
data_apartamentos["valor"] = data_apartamentos["valor"].str.replace("\n", "")
data_apartamentos = data_apartamentos[~data_apartamentos["area"].str.contains("-")]
data_apartamentos = data_apartamentos[~data_apartamentos["valor"].str.contains("A partir de ")]
data_apartamentos = data_apartamentos[~data_apartamentos["valor"].str.contains("Mês")]
data_apartamentos = data_apartamentos[~data_apartamentos["valor"].str.contains("Sob Consulta")]
data_apartamentos = data_apartamentos[~data_apartamentos["valor"].str.contains("Dia")]
data_apartamentos = data_apartamentos[~data_apartamentos["valor"].str.contains("Semana")]
data_apartamentos["valor"] = data_apartamentos["valor"].str.replace(".", "").str.replace("R", "").str.replace('[\$,]', '', regex=True).astype(float)
data_apartamentos["area"] = data_apartamentos["area"].astype(float)

# %% [markdown]
# Os modelos utilizarão de localidade e tamanho dos imóveis para identificar os preços.

# %%
data_apartamentos.head()
# Out:
#       municipio   area        lat        lng      valor
# 0  riodejaneiro   94.0 -22.913830 -43.252564   390000.0
# 2  riodejaneiro   83.0 -22.968900 -43.391418   559000.0
# 3  riodejaneiro   82.0 -22.971108 -43.190286   900000.0
# 4  riodejaneiro  200.0 -22.996820 -43.259414  1700000.0
# 5  riodejaneiro   46.0 -22.974553 -43.188991   529000.0

# %% [markdown]
# Para criar a rotina de otimização dos hiperparâmetros, optou-se pela biblioteca scikit-optimize, que utiliza da otimização bayesiana para encontrar as melhores combinações para os parâmetros do modelo.

# %%
desempenho_mdl = pd.DataFrame(columns = ["mun", "msle"])

# %%
pip install scikit-optimize
# Out:
# Collecting scikit-optimize
#   Downloading scikit_optimize-0.8.1-py2.py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 3.7 MB/s
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (0.22.2.post1)
# Collecting pyaml>=16.9
#   Downloading pyaml-21.8.3-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (1.0.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (1.19.5)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from pyaml>=16.9->scikit-optimize) (3.13)
# Installing collected packages: pyaml, scikit-optimize
# Successfully installed pyaml-21.8.3 scikit-optimize-0.8.1

# %%
from skopt import gp_minimize
from lightgbm import LGBMRegressor
import pandas as pd
import numpy as np
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import mean_squared_log_error
import pickle

for mun in data_apartamentos["municipio"].unique():

  print(f"Treinando modelo para {mun}")


  train = data_apartamentos[data_apartamentos["municipio"]==mun]
  train['valor'] = train['valor'].map(lambda x: math.log(x))

  X = train.drop(["valor", "municipio"], 1)
  y = train["valor"]

  def treinar_modelo(params):
        learning_rate = params[0]
        num_leaves = params[1]
        min_child_samples = params[2]
        subsample = params[3]
        colsample_bytree = params[4]
        feature_fraction = params[5]
        bagging_fraction = params[6]
        max_depth = params[7]
        min_split_gain = params[8]
        min_child_weight = params[9]
        
        print(params, '\n')

        mdl = LGBMRegressor(learning_rate=learning_rate, num_leaves=num_leaves, min_child_samples=min_child_samples,
                        subsample=subsample, colsample_bytree=colsample_bytree, feature_fraction=feature_fraction, 
                        bagging_fraction=bagging_fraction, max_depth=max_depth, min_split_gain=min_split_gain, 
                        min_child_weight=min_child_weight, random_state=0, subsample_freq=1, n_estimators=100)
        
        yhat = cross_val_predict(mdl, X, y, cv = 10)
        yhat_reais = np.exp(yhat)
        y_reais = np.exp(y)
        #yhat_reais = yhat
        #y_reais = y

        return mean_squared_log_error(y_reais, yhat_reais)


  space = [(1e-3, 1e-1, 'log-uniform'), #learning_rate
          (2, 128), # num_leaves
          (1, 100), # min_child_samples
          (0.05, 1.0), # subsamples
          (0.1, 1.0), # colsample_bytree
          (0.1, 0.9), # feature_fraction
          (0.8, 1), # bagging_fraction 
          (17, 25), # max_depth
          (0.001, 0.1), # min_split_gain
          (10, 25) # min_child_weight
          ] 

  resultados_gp = gp_minimize(treinar_modelo, space, random_state=1, verbose=1, n_calls=200, n_random_starts=10)

  ### append df desempenho

  desempenho_mdl = desempenho_mdl.append({"mun": mun, "msle": resultados_gp.fun}, ignore_index=True)

  ### saved model

  mdl = LGBMRegressor(learning_rate=resultados_gp.x[0], num_leaves=resultados_gp.x[1], min_child_samples=resultados_gp.x[2],
                      subsample=resultados_gp.x[3], colsample_bytree=resultados_gp.x[4], feature_fraction=resultados_gp.x[5],
                      bagging_fraction=resultados_gp.x[6], max_depth=resultados_gp.x[7], min_split_gain=resultados_gp.x[8], min_child_weight=resultados_gp.x[9],
                      random_state=0, subsample_freq=1, n_estimators=100)

  pkl_filename = f"models/apartamentos/mdl_apart_{mun}.pkl"
  with open(pkl_filename, 'wb') as file:
      pickle.dump(mdl, file)


desempenho_mdl.to_csv("models/apartamentos/desempenho_mdl.csv", index=False)
# Out:
# Treinando modelo para riodejaneiro
# Iteration No: 1 started. Evaluating function at random point.
# [0.09871192514273254, 120, 14, 0.9990884895579377, 0.3124800792567785, 0.417264581836821, 0.8775821482324015, 22, 0.09361836800979718, 23]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 0.8189
# Function value obtained: 0.1535
# Current minimum: 0.1535
# Iteration No: 2 started. Evaluating function at random point.
# [0.004232013397179603, 68, 45, 0.2680983530433343, 0.5809725180523154, 0.8311696196633865, 0.8914409615973977, 20, 0.09397365115293897, 22]
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 1.1573
# Function value obtained: 0.4959
# Current minimum: 0.1535
# Iteration No: 3 started. Evaluating function at random point.
# [0.027035912483147396, 103, 10, 0.5422449214947946, 0.8785182267810853, 0.7633175258937135, 0.9659206718788368, 19, 0.006865076928854784, 20]
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 2.5777
# Function value obtained: 0.1324
# Current minimum: 0.1324
# Iteration No: 4 started. Evaluating function at random point.
# [0.01535080081765723, 87, 42, 0.23767335308554222, 0.3606666764912312, 0.21369610837996558, 0.9566628945389772, 20, 0.0043829598073980664, 19]
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 0.9487
# Function value obtained: 0.3034
# Current minimum: 0.1324
# Iteration No: 5 started. Evaluating function at random point.
# [0.02095421812724112, 40, 45, 0.2610183201586061, 0.16602775456833962, 0.47539082115051456, 0.8192344520890924, 24, 0.01282955633009097, 18]
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 0.8090
# Function value obtained: 0.2463
# Current minimum: 0.1324
# Iteration No: 6 started. Evaluating function at random point.
# [0.0014697585967435188, 118, 91, 0.3339836065992303, 0.6259502086641363, 0.5527296219713546, 0.9227876635592112, 25, 0.026836918981940135, 13]
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 0.5838
# Function value obtained: 0.7598
# Current minimum: 0.1324
# Iteration No: 7 started. Evaluating function at random point.
# [0.011665328715255016, 122, 50, 0.5635704833824619, 0.7889365939967841, 0.1362765828597226, 0.827993223838343, 23, 0.003950334460056934, 23]
#
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 0.8155
# Function value obtained: 0.3701
# Current minimum: 0.1324
# Iteration No: 8 started. Evaluating function at random point.
# [0.012066362801915467, 58, 89, 0.40870512409354, 0.5845822248519866, 0.6218391056508338, 0.8722522040423242, 22, 0.06414581192190798, 12]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-70-4d20997bdfa4> in <module>()
#      58           ]
#      59
# ---> 60   resultados_gp = gp_minimize(treinar_modelo, space, random_state=1, verbose=1, n_calls=200, n_random_starts=10)
#      61
#      62   ### append df desempenho
#
# /usr/local/lib/python3.7/dist-packages/skopt/optimizer/gp.py in gp_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, noise, n_jobs, model_queue_size)
#     266         n_restarts_optimizer=n_restarts_optimizer,
#     267         x0=x0, y0=y0, random_state=rng, verbose=verbose,
# --> 268         callback=callback, n_jobs=n_jobs, model_queue_size=model_queue_size)
#
# /usr/local/lib/python3.7/dist-packages/skopt/optimizer/base.py in base_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, n_jobs, model_queue_size)
#     299     for n in range(n_calls):
#     300         next_x = optimizer.ask()
# --> 301         next_y = func(next_x)
#     302         result = optimizer.tell(next_x, next_y)
#     303         result.specs = specs
#
# <ipython-input-70-4d20997bdfa4> in treinar_modelo(params)
#      37                         min_child_weight=min_child_weight, random_state=0, subsample_freq=1, n_estimators=100)
#      38
# ---> 39         yhat = cross_val_predict(mdl, X, y, cv = 10)
#      40         yhat_reais = np.exp(yhat)
#      41         y_reais = np.exp(y)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py in cross_val_predict(estimator, X, y, groups, cv, n_jobs, verbose, fit_params, pre_dispatch, method)
#     753     prediction_blocks = parallel(delayed(_fit_and_predict)(
#     754         clone(estimator), X, y, train, test, verbose, fit_params, method)
# --> 755         for train, test in cv.split(X, y, groups))
#     756
#     757     # Concatenate the predictions
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1042                 self._iterating = self._original_iterator is not None
#    1043
# -> 1044             while self.dispatch_one_batch(iterator):
#    1045                 pass
#    1046
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     857                 return False
#     858             else:
# --> 859                 self._dispatch(tasks)
#     860                 return True
#     861
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in _dispatch(self, batch)
#     775         with self._lock:
#     776             job_idx = len(self._jobs)
# --> 777             job = self._backend.apply_async(batch, callback=cb)
#     778             # A job can complete so quickly than its callback is
#     779             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.7/dist-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /usr/local/lib/python3.7/dist-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in __call__(self)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in <listcomp>(.0)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py in _fit_and_predict(estimator, X, y, train, test, verbose, fit_params, method)
#     839         estimator.fit(X_train, **fit_params)
#     840     else:
# --> 841         estimator.fit(X_train, y_train, **fit_params)
#     842     func = getattr(estimator, method)
#     843     predictions = func(X_test)
#
# /usr/local/lib/python3.7/dist-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     683                                        verbose=verbose, feature_name=feature_name,
#     684                                        categorical_feature=categorical_feature,
# --> 685                                        callbacks=callbacks)
#     686         return self
#     687
#
# /usr/local/lib/python3.7/dist-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     542                               verbose_eval=verbose, feature_name=feature_name,
#     543                               categorical_feature=categorical_feature,
# --> 544                               callbacks=callbacks)
#     545
#     546         if evals_result:
#
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     216                                     evaluation_result_list=None))
#     217
# --> 218         booster.update(fobj=fobj)
#     219
#     220         evaluation_result_list = []
#
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py in update(self, train_set, fobj)
#    1800             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    1801                 self.handle,
# -> 1802                 ctypes.byref(is_finished)))
#    1803             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    1804             return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
desempenho_mdl
# Out:
#               mun      msle
# 0    riodejaneiro  0.120337
# 1    riodejaneiro  0.120337
# 2        brasília  0.109812
# 3        salvador  0.117610
# 4       fortaleza  0.119315
# 5   belohorizonte  0.114709
# 6          manaus  0.148878
# 7        curitiba  0.121017
# 8         goiânia  0.095487
# 9           belém  0.100101
# 10    portoalegre  0.128042
# 11        sãoluís  0.115541
# 12         maceió  0.110850
# 13       sãopaulo  0.117338

# %% [markdown]
# ### Modelagem - Residencias

# %%
import pandas as pd

data_residen = pd.read_csv("data/html_residen/data_residen.csv")
data_residen = data_residen[["municipio", "area", "lat", "lng", "valor"]]

# %%
data_residen = data_residen.drop_duplicates()
data_residen["municipio"] = data_residen["municipio"].str.lower()
data_residen["area"] = data_residen["area"].str.replace("\n", "")
data_residen["valor"] = data_residen["valor"].str.replace("\n", "")
data_residen = data_residen[~data_residen["area"].str.contains("-")]
data_residen = data_residen[~data_residen["valor"].str.contains("A partir de ")]
data_residen = data_residen[~data_residen["valor"].str.contains("Mês")]
data_residen = data_residen[~data_residen["valor"].str.contains("Sob Consulta")]
data_residen = data_residen[~data_residen["valor"].str.contains("Dia")]
data_residen = data_residen[~data_residen["valor"].str.contains("Semana")]
data_residen["valor"] = data_residen["valor"].str.replace(".", "").str.replace("R", "").str.replace('[\$,]', '', regex=True).astype(float)
data_residen["area"] = data_residen["area"].astype(float)

# %%
desempenho_mdl = pd.DataFrame(columns = ["mun", "msle"])

# %%
from skopt import gp_minimize
from lightgbm import LGBMRegressor
import pandas as pd
import numpy as np
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import mean_squared_log_error
import pickle
import math

for mun in data_residen["municipio"].unique():

  print(f"Treinando modelo para {mun}")

  train = data_residen[data_residen["municipio"]==mun]
  train['valor'] = train['valor'].map(lambda x: math.log(x))

  X = train.drop(["valor", "municipio"], 1)
  y = train["valor"]

  def treinar_modelo(params):
        learning_rate = params[0]
        num_leaves = params[1]
        min_child_samples = params[2]
        subsample = params[3]
        colsample_bytree = params[4]
        feature_fraction = params[5]
        bagging_fraction = params[6]
        max_depth = params[7]
        min_split_gain = params[8]
        min_child_weight = params[9]
        
        print(params, '\n')

        mdl = LGBMRegressor(learning_rate=learning_rate, num_leaves=num_leaves, min_child_samples=min_child_samples,
                        subsample=subsample, colsample_bytree=colsample_bytree, feature_fraction=feature_fraction, 
                        bagging_fraction=bagging_fraction, max_depth=max_depth, min_split_gain=min_split_gain, 
                        min_child_weight=min_child_weight, random_state=0, subsample_freq=1, n_estimators=100)
        
        yhat = cross_val_predict(mdl, X, y, cv = 10)
        yhat_reais = np.exp(yhat)
        y_reais = np.exp(y)
        #yhat_reais = yhat
        #y_reais = y

        return mean_squared_log_error(y_reais, yhat_reais)


  space = [(1e-3, 1e-1, 'log-uniform'), #learning_rate
          (2, 128), # num_leaves
          (1, 100), # min_child_samples
          (0.05, 1.0), # subsamples
          (0.1, 1.0), # colsample_bytree
          (0.1, 0.9), # feature_fraction
          (0.8, 1), # bagging_fraction 
          (17, 25), # max_depth
          (0.001, 0.1), # min_split_gain
          (10, 25) # min_child_weight
          ] 

  resultados_gp = gp_minimize(treinar_modelo, space, random_state=1, verbose=1, n_calls=200, n_random_starts=10)

  ### append df desempenho

  desempenho_mdl = desempenho_mdl.append({"mun": mun, "msle": resultados_gp.fun}, ignore_index=True)

  ### saved model

  mdl = LGBMRegressor(learning_rate=resultados_gp.x[0], num_leaves=resultados_gp.x[1], min_child_samples=resultados_gp.x[2],
                      subsample=resultados_gp.x[3], colsample_bytree=resultados_gp.x[4], feature_fraction=resultados_gp.x[5],
                      bagging_fraction=resultados_gp.x[6], max_depth=resultados_gp.x[7], min_split_gain=resultados_gp.x[8], min_child_weight=resultados_gp.x[9],
                      random_state=0, subsample_freq=1, n_estimators=100)

  pkl_filename = f"models/residencias/mdl_residen_{mun}.pkl"
  with open(pkl_filename, 'wb') as file:
      pickle.dump(mdl, file)


desempenho_mdl.to_csv("models/residencias/desempenho_mdl.csv", index=False)
# Out:
# Treinando modelo para sãopaulo
# Iteration No: 1 started. Evaluating function at random point.
# [0.09871192514273254, 120, 14, 0.9990884895579377, 0.3124800792567785, 0.417264581836821, 0.8775821482324015, 22, 0.09361836800979718, 23]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 0.9540
# Function value obtained: 0.2003
# Current minimum: 0.2003
# Iteration No: 2 started. Evaluating function at random point.
# [0.004232013397179603, 68, 45, 0.2680983530433343, 0.5809725180523154, 0.8311696196633865, 0.8914409615973977, 20, 0.09397365115293897, 22]
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 1.1203
# Function value obtained: 0.6067
# Current minimum: 0.2003
# Iteration No: 3 started. Evaluating function at random point.
# [0.027035912483147396, 103, 10, 0.5422449214947946, 0.8785182267810853, 0.7633175258937135, 0.9659206718788368, 19, 0.006865076928854784, 20]
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 2.3672
# Function value obtained: 0.1532
# Current minimum: 0.1532
# Iteration No: 4 started. Evaluating function at random point.
# [0.01535080081765723, 87, 42, 0.23767335308554222, 0.3606666764912312, 0.21369610837996558, 0.9566628945389772, 20, 0.0043829598073980664, 19]
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 0.9480
# Function value obtained: 0.3843
# Current minimum: 0.1532
# Iteration No: 5 started. Evaluating function at random point.
# [0.02095421812724112, 40, 45, 0.2610183201586061, 0.16602775456833962, 0.47539082115051456, 0.8192344520890924, 24, 0.01282955633009097, 18]
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 0.8348
# Function value obtained: 0.3089
# Current minimum: 0.1532
# Iteration No: 6 started. Evaluating function at random point.
# [0.0014697585967435188, 118, 91, 0.3339836065992303, 0.6259502086641363, 0.5527296219713546, 0.9227876635592112, 25, 0.026836918981940135, 13]
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 0.7443
# Function value obtained: 0.9396
# Current minimum: 0.1532
# Iteration No: 7 started. Evaluating function at random point.
# [0.011665328715255016, 122, 50, 0.5635704833824619, 0.7889365939967841, 0.1362765828597226, 0.827993223838343, 23, 0.003950334460056934, 23]
#
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 0.8183
# Function value obtained: 0.4620
# Current minimum: 0.1532
# Iteration No: 8 started. Evaluating function at random point.
# [0.012066362801915467, 58, 89, 0.40870512409354, 0.5845822248519866, 0.6218391056508338, 0.8722522040423242, 22, 0.06414581192190798, 12]
#
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 0.6153
# Function value obtained: 0.4550
# Current minimum: 0.1532
# Iteration No: 9 started. Evaluating function at random point.
# [0.024010940718920456, 84, 36, 0.775071400079366, 0.4208785512022495, 0.7022306825404836, 0.9762683659268023, 17, 0.050312797893195434, 11]
#
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 1.3633
# Function value obtained: 0.1632
# Current minimum: 0.1532
# Iteration No: 10 started. Evaluating function at random point.
# [0.03748892170175449, 10, 36, 0.9447451013157516, 0.4418229580918275, 0.7103360587559912, 0.9543189996088736, 19, 0.07750117553098015, 12]
#
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 1.5028
# Function value obtained: 0.1550
# Current minimum: 0.1532
# Iteration No: 11 started. Searching for the next optimal point.
# [0.028917543339141434, 122, 4, 0.7864180645063559, 0.95960958309487, 0.7684824250306284, 1.0, 17, 0.016021735531913057, 19]
#
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 3.4771
# Function value obtained: 0.1510
# Current minimum: 0.1510
# Iteration No: 12 started. Searching for the next optimal point.
# [0.05815591913613969, 128, 14, 1.0, 0.13437233783105407, 0.9, 0.8632460451080148, 17, 0.07438960231267364, 10]
#
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 2.6953
# Function value obtained: 0.1420
# Current minimum: 0.1420
# Iteration No: 13 started. Searching for the next optimal point.
# [0.03554726451489207, 103, 21, 0.667522254046945, 0.30385604191232285, 0.9, 0.9593459637771236, 17, 0.04502725302972693, 10]
#
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 2.9292
# Function value obtained: 0.1451
# Current minimum: 0.1420
# Iteration No: 14 started. Searching for the next optimal point.
# [0.03473669719617455, 99, 12, 1.0, 0.8436212994883229, 0.9, 1.0, 17, 0.05532638253777115, 13]
#
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 3.2302
# Function value obtained: 0.1488
# Current minimum: 0.1420
# Iteration No: 15 started. Searching for the next optimal point.
# [0.1, 2, 100, 0.05, 0.1, 0.9, 0.8, 17, 0.001, 10]
#
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 1.0737
# Function value obtained: 0.2245
# Current minimum: 0.1420
# Iteration No: 16 started. Searching for the next optimal point.
# [0.049308701291327764, 128, 100, 0.05, 0.1, 0.3713717146272565, 0.8, 17, 0.001, 10]
#
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 1.3845
# Function value obtained: 0.2111
# Current minimum: 0.1420
# Iteration No: 17 started. Searching for the next optimal point.
# [0.060371024109877214, 62, 100, 0.05, 0.1, 0.9, 0.8, 25, 0.001, 18]
#
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 1.5362
# Function value obtained: 0.1501
# Current minimum: 0.1420
# Iteration No: 18 started. Searching for the next optimal point.
# [0.07105594584751554, 50, 100, 0.05, 0.1, 0.10859168889274082, 1.0, 21, 0.0334116096060559, 11]
#
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 1.5086
# Function value obtained: 0.1997
# Current minimum: 0.1420
# Iteration No: 19 started. Searching for the next optimal point.
# [0.04345646777947542, 113, 1, 0.34649341807092315, 0.1, 0.9, 0.8, 25, 0.1, 15]
#
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 2.6423
# Function value obtained: 0.1409
# Current minimum: 0.1409
# Iteration No: 20 started. Searching for the next optimal point.
# [0.058471941712938666, 55, 1, 1.0, 0.1, 0.9, 0.9342369791591019, 25, 0.1, 13]
#
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 2.1682
# Function value obtained: 0.1406
# Current minimum: 0.1406
# Iteration No: 21 started. Searching for the next optimal point.
# [0.051985786296861604, 128, 1, 1.0, 0.1, 0.9, 0.9532424576357497, 21, 0.1, 11]
#
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 2.7954
# Function value obtained: 0.1431
# Current minimum: 0.1406
# Iteration No: 22 started. Searching for the next optimal point.
# [0.03274346968622125, 2, 1, 0.27499891171468166, 0.1, 0.9, 0.8311158865780714, 21, 0.1, 10]
#
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 1.2608
# Function value obtained: 0.3385
# Current minimum: 0.1406
# Iteration No: 23 started. Searching for the next optimal point.
# [0.1, 128, 1, 0.05, 1.0, 0.1, 1.0, 25, 0.1, 25]
#
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 1.7347
# Function value obtained: 0.1996
# Current minimum: 0.1406
# Iteration No: 24 started. Searching for the next optimal point.
# [0.06558569901373895, 2, 100, 1.0, 1.0, 0.9, 0.8175402059643585, 25, 0.001, 25]
#
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 1.2138
# Function value obtained: 0.2546
# Current minimum: 0.1406
# Iteration No: 25 started. Searching for the next optimal point.
# [0.056530005952125144, 128, 100, 0.5731164562633977, 1.0, 0.26873577065458265, 1.0, 17, 0.001, 18]
#
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 1.5152
# Function value obtained: 0.2056
# Current minimum: 0.1406
# Iteration No: 26 started. Searching for the next optimal point.
# [0.044384925209354484, 55, 1, 1.0, 0.1, 0.7114371016718244, 1.0, 18, 0.1, 10]
#
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 2.4707
# Function value obtained: 0.1421
# Current minimum: 0.1406
# Iteration No: 27 started. Searching for the next optimal point.
# [0.03418583384125111, 104, 1, 0.6254256732206928, 0.1, 0.9, 0.9014421162113971, 25, 0.0704998427400202, 25]
#
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 2.8621
# Function value obtained: 0.1442
# Current minimum: 0.1406
# Iteration No: 28 started. Searching for the next optimal point.
# [0.1, 2, 1, 1.0, 0.326976321906266, 0.44589574173257474, 0.998129327991607, 20, 0.1, 10]
#
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 1.1787
# Function value obtained: 0.2223
# Current minimum: 0.1406
# Iteration No: 29 started. Searching for the next optimal point.
# [0.06905454513783923, 86, 1, 0.313139100419155, 0.1, 0.9, 0.9282877916179574, 25, 0.08052275235706485, 13]
#
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 2.5520
# Function value obtained: 0.1424
# Current minimum: 0.1406
# Iteration No: 30 started. Searching for the next optimal point.
# [0.026102556107997794, 2, 25, 1.0, 0.9739890771619708, 0.1, 0.8930021636859847, 18, 0.001, 23]
#
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 1.2549
# Function value obtained: 0.4551
# Current minimum: 0.1406
# Iteration No: 31 started. Searching for the next optimal point.
# [0.05148306548803084, 32, 37, 1.0, 0.1, 0.7564931927512704, 1.0, 19, 0.1, 11]
#
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 1.8660
# Function value obtained: 0.1418
# Current minimum: 0.1406
# Iteration No: 32 started. Searching for the next optimal point.
# [0.1, 128, 1, 0.23672214457624868, 0.1, 0.9, 1.0, 17, 0.001, 25]
#
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 3.4205
# Function value obtained: 0.1452
# Current minimum: 0.1406
# Iteration No: 33 started. Searching for the next optimal point.
# [0.04423298120832127, 24, 1, 1.0, 0.1, 0.6651632369716787, 1.0, 18, 0.1, 10]
#
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 2.0180
# Function value obtained: 0.2163
# Current minimum: 0.1406
# Iteration No: 34 started. Searching for the next optimal point.
# [0.06749958387972284, 73, 55, 0.05, 0.1, 0.7531295405108817, 1.0, 25, 0.050862273507612264, 10]
#
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 2.4488
# Function value obtained: 0.1425
# Current minimum: 0.1406
# Iteration No: 35 started. Searching for the next optimal point.
# [0.05780386949224739, 83, 49, 0.8450878252384709, 0.1, 0.7984374906649203, 1.0, 25, 0.0891191393260267, 14]
#
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 2.2051
# Function value obtained: 0.1420
# Current minimum: 0.1406
# Iteration No: 36 started. Searching for the next optimal point.
# [0.050266009890063745, 94, 16, 0.6753302689985214, 0.1, 0.9, 1.0, 19, 0.06134719533860282, 14]
#
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 3.3137
# Function value obtained: 0.1447
# Current minimum: 0.1406
# Iteration No: 37 started. Searching for the next optimal point.
# [0.0499800771429507, 95, 12, 0.6514296073179817, 0.1, 0.9, 1.0, 19, 0.05534922545915897, 16]
#
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 3.2663
# Function value obtained: 0.1453
# Current minimum: 0.1406
# Iteration No: 38 started. Searching for the next optimal point.
# [0.050712420811174816, 45, 43, 1.0, 0.23933268503760402, 0.7469754797230351, 0.9215833100301577, 20, 0.1, 11]
#
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 2.4397
# Function value obtained: 0.1413
# Current minimum: 0.1406
# Iteration No: 39 started. Searching for the next optimal point.
# [0.1, 128, 100, 0.05, 1.0, 0.9, 1.0, 17, 0.1, 10]
#
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 1.7931
# Function value obtained: 0.1483
# Current minimum: 0.1406
# Iteration No: 40 started. Searching for the next optimal point.
# [0.04533259468136453, 91, 100, 1.0, 1.0, 0.6825687960262617, 0.8, 17, 0.024639656845867348, 25]
#
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 1.9966
# Function value obtained: 0.1530
# Current minimum: 0.1406
# Iteration No: 41 started. Searching for the next optimal point.
# [0.04391513048859097, 88, 100, 0.05, 0.1, 0.6941152887159999, 1.0, 25, 0.001, 10]
#
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 2.1131
# Function value obtained: 0.1505
# Current minimum: 0.1406
# Iteration No: 42 started. Searching for the next optimal point.
# [0.037136903296930736, 74, 1, 1.0, 0.3967305742544428, 0.7333804732565653, 0.8, 17, 0.1, 21]
#
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 3.0505
# Function value obtained: 0.1416
# Current minimum: 0.1406
# Iteration No: 43 started. Searching for the next optimal point.
# [0.1, 9, 100, 0.05, 0.1, 0.2520311702957992, 0.8435881059029698, 17, 0.0014246309897534884, 22]
#
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 1.9168
# Function value obtained: 0.1939
# Current minimum: 0.1406
# Iteration No: 44 started. Searching for the next optimal point.
# [0.09093640558008742, 64, 1, 1.0, 0.29418314710715154, 0.8508538997615948, 0.9759847676585307, 19, 0.1, 10]
#
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 2.3975
# Function value obtained: 0.1418
# Current minimum: 0.1406
# Iteration No: 45 started. Searching for the next optimal point.
# [0.09518679852910195, 128, 1, 1.0, 0.1, 0.7397394028681601, 1.0, 17, 0.1, 10]
#
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 2.5724
# Function value obtained: 0.1462
# Current minimum: 0.1406
# Iteration No: 46 started. Searching for the next optimal point.
# [0.1, 76, 100, 0.5635295107491957, 0.1, 0.18363573985869955, 0.9359591794897373, 25, 0.1, 10]
#
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 1.9093
# Function value obtained: 0.1946
# Current minimum: 0.1406
# Iteration No: 47 started. Searching for the next optimal point.
# [0.1, 128, 1, 1.0, 1.0, 0.6039441584197179, 1.0, 25, 0.1, 10]
#
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 2.5216
# Function value obtained: 0.2130
# Current minimum: 0.1406
# Iteration No: 48 started. Searching for the next optimal point.
# [0.04205723512578029, 128, 1, 1.0, 0.7657209311264012, 0.7099640900277888, 1.0, 17, 0.1, 10]
#
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 3.6734
# Function value obtained: 0.1462
# Current minimum: 0.1406
# Iteration No: 49 started. Searching for the next optimal point.
# [0.03432350956633616, 128, 1, 1.0, 0.15969338761254212, 0.8654372563896544, 0.8859506568519881, 25, 0.1, 13]
#
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 3.6827
# Function value obtained: 0.1450
# Current minimum: 0.1406
# Iteration No: 50 started. Searching for the next optimal point.
# [0.05625187934647821, 37, 1, 0.17499339448402262, 1.0, 0.3504840757812684, 1.0, 17, 0.06555401956689197, 12]
#
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 2.4359
# Function value obtained: 0.2111
# Current minimum: 0.1406
# Iteration No: 51 started. Searching for the next optimal point.
# [0.1, 2, 1, 0.05, 1.0, 0.1, 1.0, 17, 0.001, 25]
#
# Iteration No: 51 ended. Search finished for the next optimal point.
# Time taken: 1.7795
# Function value obtained: 0.2222
# Current minimum: 0.1406
# Iteration No: 52 started. Searching for the next optimal point.
# [0.001, 2, 100, 0.05, 0.1, 0.1, 1.0, 17, 0.1, 10]
#
# Iteration No: 52 ended. Search finished for the next optimal point.
# Time taken: 1.6377
# Function value obtained: 1.0111
# Current minimum: 0.1406
# Iteration No: 53 started. Searching for the next optimal point.
# [0.06008540996683705, 88, 88, 0.05, 0.32146654954512743, 0.8378743747330587, 1.0, 22, 0.018385037293923674, 10]
#
# Iteration No: 53 ended. Search finished for the next optimal point.
# Time taken: 2.3168
# Function value obtained: 0.1473
# Current minimum: 0.1406
# Iteration No: 54 started. Searching for the next optimal point.
# [0.05555925886821669, 72, 1, 0.9828052284199019, 0.1, 0.7453382712746703, 0.9881997652842327, 17, 0.1, 10]
#
# Iteration No: 54 ended. Search finished for the next optimal point.
# Time taken: 3.1198
# Function value obtained: 0.1426
# Current minimum: 0.1406
# Iteration No: 55 started. Searching for the next optimal point.
# [0.046346871945815195, 68, 15, 0.1433817211641787, 0.1, 0.8373919562474995, 0.9080141295342891, 25, 0.083355284492018, 10]
#
# Iteration No: 55 ended. Search finished for the next optimal point.
# Time taken: 3.0908
# Function value obtained: 0.1403
# Current minimum: 0.1403
# Iteration No: 56 started. Searching for the next optimal point.
# [0.04489267058001555, 20, 48, 0.8288410609517766, 0.21396179799385956, 0.7371366846304623, 1.0, 17, 0.07390110054749395, 10]
#
# Iteration No: 56 ended. Search finished for the next optimal point.
# Time taken: 2.4163
# Function value obtained: 0.1447
# Current minimum: 0.1403
# Iteration No: 57 started. Searching for the next optimal point.
# [0.035965431258646895, 40, 1, 1.0, 0.10496292058213362, 0.7422720408405276, 1.0, 25, 0.1, 10]
#
# Iteration No: 57 ended. Search finished for the next optimal point.
# Time taken: 2.8989
# Function value obtained: 0.1435
# Current minimum: 0.1403
# Iteration No: 58 started. Searching for the next optimal point.
# [0.1, 55, 1, 1.0, 0.3971671913833674, 0.7790764684256251, 0.8, 25, 0.1, 24]
#
# Iteration No: 58 ended. Search finished for the next optimal point.
# Time taken: 2.8532
# Function value obtained: 0.1401
# Current minimum: 0.1401
# Iteration No: 59 started. Searching for the next optimal point.
# [0.1, 128, 1, 0.9727253357442981, 0.10752787679183964, 0.7951282749527627, 0.8096787804585198, 23, 0.1, 12]
#
# Iteration No: 59 ended. Search finished for the next optimal point.
# Time taken: 2.9400
# Function value obtained: 0.1436
# Current minimum: 0.1401
# Iteration No: 60 started. Searching for the next optimal point.
# [0.1, 71, 1, 1.0, 0.1, 0.9, 0.8, 25, 0.1, 10]
#
# Iteration No: 60 ended. Search finished for the next optimal point.
# Time taken: 3.0392
# Function value obtained: 0.1415
# Current minimum: 0.1401
# Iteration No: 61 started. Searching for the next optimal point.
# [0.029769046565987327, 128, 1, 1.0, 0.1, 0.9, 0.8, 25, 0.1, 25]
#
# Iteration No: 61 ended. Search finished for the next optimal point.
# Time taken: 3.4973
# Function value obtained: 0.1475
# Current minimum: 0.1401
# Iteration No: 62 started. Searching for the next optimal point.
# [0.06769846211770807, 60, 1, 1.0, 1.0, 0.8001386267935963, 0.8, 25, 0.1, 10]
#
# Iteration No: 62 ended. Search finished for the next optimal point.
# Time taken: 3.4187
# Function value obtained: 0.1407
# Current minimum: 0.1401
# Iteration No: 63 started. Searching for the next optimal point.
# [0.1, 2, 1, 1.0, 1.0, 0.7539367192499619, 1.0, 25, 0.1, 11]
#
# Iteration No: 63 ended. Search finished for the next optimal point.
# Time taken: 2.2808
# Function value obtained: 0.2247
# Current minimum: 0.1401
# Iteration No: 64 started. Searching for the next optimal point.
# [0.1, 83, 1, 1.0, 0.1, 0.7804806324573966, 0.9286972320168527, 17, 0.1, 25]
#
# Iteration No: 64 ended. Search finished for the next optimal point.
# Time taken: 2.8842
# Function value obtained: 0.1402
# Current minimum: 0.1401
# Iteration No: 65 started. Searching for the next optimal point.
# [0.055078487277590814, 128, 1, 0.9623972364884786, 0.1, 0.7708559290603094, 0.8031496475394939, 18, 0.059267017839609026, 25]
#
# Iteration No: 65 ended. Search finished for the next optimal point.
# Time taken: 3.5966
# Function value obtained: 0.1399
# Current minimum: 0.1399
# Iteration No: 66 started. Searching for the next optimal point.
# [0.06049710601125036, 65, 1, 1.0, 0.1, 0.8590707655677033, 0.9700157240892601, 24, 0.1, 25]
#
# Iteration No: 66 ended. Search finished for the next optimal point.
# Time taken: 3.2339
# Function value obtained: 0.1407
# Current minimum: 0.1399
# Iteration No: 67 started. Searching for the next optimal point.
# [0.1, 80, 100, 0.05, 0.1, 0.3225334261672841, 0.8, 17, 0.006385127818686563, 25]
#
# Iteration No: 67 ended. Search finished for the next optimal point.
# Time taken: 2.6506
# Function value obtained: 0.1946
# Current minimum: 0.1399
# Iteration No: 68 started. Searching for the next optimal point.
# [0.03654433766133881, 107, 1, 1.0, 0.1, 0.7260726234290068, 0.8, 25, 0.001, 19]
#
# Iteration No: 68 ended. Search finished for the next optimal point.
# Time taken: 4.2936
# Function value obtained: 0.1426
# Current minimum: 0.1399
# Iteration No: 69 started. Searching for the next optimal point.
# [0.04336617806828849, 113, 1, 0.05, 0.1, 0.8172987051268829, 0.8, 17, 0.1, 25]
#
# Iteration No: 69 ended. Search finished for the next optimal point.
# Time taken: 3.5303
# Function value obtained: 0.1401
# Current minimum: 0.1399
# Iteration No: 70 started. Searching for the next optimal point.
# [0.04127329240453696, 41, 1, 0.05, 0.7723103483390604, 0.7357525745550528, 0.9574650253977415, 17, 0.001, 25]
#
# Iteration No: 70 ended. Search finished for the next optimal point.
# Time taken: 3.4370
# Function value obtained: 0.1411
# Current minimum: 0.1399
# Iteration No: 71 started. Searching for the next optimal point.
# [0.03325088752255548, 128, 1, 0.08216260327273854, 0.1, 0.6749670959071004, 0.8, 17, 0.0441787012306651, 25]
#
# Iteration No: 71 ended. Search finished for the next optimal point.
# Time taken: 3.9845
# Function value obtained: 0.1441
# Current minimum: 0.1399
# Iteration No: 72 started. Searching for the next optimal point.
# [0.040982783606958645, 128, 59, 1.0, 0.1, 0.5444807944953362, 0.8, 17, 0.1, 25]
#
# Iteration No: 72 ended. Search finished for the next optimal point.
# Time taken: 2.5543
# Function value obtained: 0.2206
# Current minimum: 0.1399
# Iteration No: 73 started. Searching for the next optimal point.
# [0.1, 63, 1, 0.05, 0.1, 0.7984756725022221, 1.0, 17, 0.1, 25]
#
# Iteration No: 73 ended. Search finished for the next optimal point.
# Time taken: 2.8840
# Function value obtained: 0.1411
# Current minimum: 0.1399
# Iteration No: 74 started. Searching for the next optimal point.
# [0.040385450945378196, 91, 1, 1.0, 0.1, 0.8461832163623887, 0.8, 25, 0.1, 25]
#
# Iteration No: 74 ended. Search finished for the next optimal point.
# Time taken: 3.5376
# Function value obtained: 0.1408
# Current minimum: 0.1399
# Iteration No: 75 started. Searching for the next optimal point.
# [0.061405169786012126, 128, 1, 0.5826667800223079, 0.6719622432693833, 0.8281054013880136, 1.0, 25, 0.1, 25]
#
# Iteration No: 75 ended. Search finished for the next optimal point.
# Time taken: 3.3390
# Function value obtained: 0.1413
# Current minimum: 0.1399
# Iteration No: 76 started. Searching for the next optimal point.
# [0.02973405146379355, 128, 100, 0.920171725150405, 0.1, 0.7136686326882543, 0.8, 25, 0.1, 25]
#
# Iteration No: 76 ended. Search finished for the next optimal point.
# Time taken: 2.6506
# Function value obtained: 0.1666
# Current minimum: 0.1399
# Iteration No: 77 started. Searching for the next optimal point.
# [0.0756778906745082, 107, 1, 0.05, 1.0, 0.7641818924991257, 0.8, 25, 0.001, 23]
#
# Iteration No: 77 ended. Search finished for the next optimal point.
# Time taken: 3.8193
# Function value obtained: 0.1417
# Current minimum: 0.1399
# Iteration No: 78 started. Searching for the next optimal point.
# [0.04898714913861323, 128, 1, 0.06010257981733695, 0.1, 0.6727736583751327, 0.8, 17, 0.001, 10]
#
# Iteration No: 78 ended. Search finished for the next optimal point.
# Time taken: 5.2978
# Function value obtained: 0.1446
# Current minimum: 0.1399
# Iteration No: 79 started. Searching for the next optimal point.
# [0.07524417941346187, 62, 1, 0.05113067167735329, 0.1, 0.7749261783456767, 0.8, 17, 0.001, 16]
#
# Iteration No: 79 ended. Search finished for the next optimal point.
# Time taken: 3.5954
# Function value obtained: 0.1423
# Current minimum: 0.1399
# Iteration No: 80 started. Searching for the next optimal point.
# [0.04717845107013618, 128, 1, 0.9242184528354753, 0.22629305389859222, 0.8012631199152409, 0.8486386387906388, 21, 0.001, 10]
#
# Iteration No: 80 ended. Search finished for the next optimal point.
# Time taken: 5.2181
# Function value obtained: 0.1445
# Current minimum: 0.1399
# Iteration No: 81 started. Searching for the next optimal point.
# [0.1, 59, 1, 0.05, 1.0, 0.9, 1.0, 25, 0.1, 21]
#
# Iteration No: 81 ended. Search finished for the next optimal point.
# Time taken: 2.7296
# Function value obtained: 0.1423
# Current minimum: 0.1399
# Iteration No: 82 started. Searching for the next optimal point.
# [0.03686524941920285, 103, 1, 0.05, 0.1, 0.6924679340539658, 0.8511857097805969, 23, 0.09951356889141978, 25]
#
# Iteration No: 82 ended. Search finished for the next optimal point.
# Time taken: 3.6819
# Function value obtained: 0.1422
# Current minimum: 0.1399
# Iteration No: 83 started. Searching for the next optimal point.
# [0.1, 128, 1, 0.05, 1.0, 0.8529003406467789, 0.8243479162435007, 18, 0.1, 12]
#
# Iteration No: 83 ended. Search finished for the next optimal point.
# Time taken: 3.2782
# Function value obtained: 0.1447
# Current minimum: 0.1399
# Iteration No: 84 started. Searching for the next optimal point.
# [0.1, 87, 1, 0.05, 0.4095140634884368, 0.7355272555781887, 0.929569520022358, 18, 0.1, 21]
#
# Iteration No: 84 ended. Search finished for the next optimal point.
# Time taken: 3.0414
# Function value obtained: 0.1402
# Current minimum: 0.1399
# Iteration No: 85 started. Searching for the next optimal point.
# [0.04166714805692241, 90, 1, 0.05, 1.0, 0.7812222537864071, 0.9682484454939575, 17, 0.1, 16]
#
# Iteration No: 85 ended. Search finished for the next optimal point.
# Time taken: 4.1372
# Function value obtained: 0.1431
# Current minimum: 0.1399
# Iteration No: 86 started. Searching for the next optimal point.
# [0.061178185938006356, 113, 1, 0.05, 0.1, 0.720357362483188, 1.0, 17, 0.0652184044732293, 25]
#
# Iteration No: 86 ended. Search finished for the next optimal point.
# Time taken: 3.8130
# Function value obtained: 0.1423
# Current minimum: 0.1399
# Iteration No: 87 started. Searching for the next optimal point.
# [0.1, 2, 100, 1.0, 0.7739441913043731, 0.3463000260836855, 0.8, 18, 0.001, 25]
#
# Iteration No: 87 ended. Search finished for the next optimal point.
# Time taken: 2.5805
# Function value obtained: 0.2226
# Current minimum: 0.1399
# Iteration No: 88 started. Searching for the next optimal point.
# [0.03539342759379944, 10, 1, 0.7380202351338809, 0.3545425930949002, 0.750262266778242, 0.8, 17, 0.035342075240995016, 22]
#
# Iteration No: 88 ended. Search finished for the next optimal point.
# Time taken: 2.8100
# Function value obtained: 0.1557
# Current minimum: 0.1399
# Iteration No: 89 started. Searching for the next optimal point.
# [0.051063002983968375, 128, 1, 0.955997048525447, 0.1, 0.1, 0.8, 17, 0.001, 12]
#
# Iteration No: 89 ended. Search finished for the next optimal point.
# Time taken: 4.5131
# Function value obtained: 0.2242
# Current minimum: 0.1399
# Iteration No: 90 started. Searching for the next optimal point.
# [0.1, 67, 1, 0.05, 0.1, 0.4522882369724912, 0.8039774702206786, 17, 0.001, 21]
#
# Iteration No: 90 ended. Search finished for the next optimal point.
# Time taken: 3.9757
# Function value obtained: 0.2032
# Current minimum: 0.1399
# Iteration No: 91 started. Searching for the next optimal point.
# [0.1, 77, 1, 0.05, 1.0, 0.7689780658300381, 1.0, 25, 0.1, 10]
#
# Iteration No: 91 ended. Search finished for the next optimal point.
# Time taken: 3.5985
# Function value obtained: 0.1426
# Current minimum: 0.1399
# Iteration No: 92 started. Searching for the next optimal point.
# [0.05160755671983103, 55, 1, 0.30312357918999866, 0.1, 0.7926008108216596, 1.0, 20, 0.1, 25]
#
# Iteration No: 92 ended. Search finished for the next optimal point.
# Time taken: 4.0024
# Function value obtained: 0.1414
# Current minimum: 0.1399
# Iteration No: 93 started. Searching for the next optimal point.
# [0.07257805154510501, 128, 1, 0.05, 0.1, 0.7864635557714011, 1.0, 17, 0.1, 25]
#
# Iteration No: 93 ended. Search finished for the next optimal point.
# Time taken: 3.7906
# Function value obtained: 0.1413
# Current minimum: 0.1399
# Iteration No: 94 started. Searching for the next optimal point.
# [0.041211231712698464, 128, 1, 0.7566590317030425, 1.0, 0.9, 0.9251321843274395, 24, 0.001, 25]
#
# Iteration No: 94 ended. Search finished for the next optimal point.
# Time taken: 4.8131
# Function value obtained: 0.1420
# Current minimum: 0.1399
# Iteration No: 95 started. Searching for the next optimal point.
# [0.1, 49, 1, 1.0, 0.1, 0.8536724732822044, 0.8, 25, 0.1, 24]
#
# Iteration No: 95 ended. Search finished for the next optimal point.
# Time taken: 3.5952
# Function value obtained: 0.1402
# Current minimum: 0.1399
# Iteration No: 96 started. Searching for the next optimal point.
# [0.1, 99, 100, 1.0, 0.12052978003902855, 0.7517468186234812, 0.8, 17, 0.001, 16]
#
# Iteration No: 96 ended. Search finished for the next optimal point.
# Time taken: 3.1852
# Function value obtained: 0.1466
# Current minimum: 0.1399
# Iteration No: 97 started. Searching for the next optimal point.
# [0.1, 84, 1, 0.3987452481059859, 0.1, 0.8331648092771066, 0.8477023630706891, 25, 0.1, 25]
#
# Iteration No: 97 ended. Search finished for the next optimal point.
# Time taken: 3.7343
# Function value obtained: 0.1405
# Current minimum: 0.1399
# Iteration No: 98 started. Searching for the next optimal point.
# [0.1, 128, 1, 0.05, 1.0, 0.7152791502249315, 0.8, 25, 0.001, 25]
#
# Iteration No: 98 ended. Search finished for the next optimal point.
# Time taken: 5.7487
# Function value obtained: 0.1426
# Current minimum: 0.1399
# Iteration No: 99 started. Searching for the next optimal point.
# [0.02465298401678801, 128, 1, 0.05, 0.40214478558763855, 0.8366618683189021, 0.8673555255000118, 18, 0.001, 25]
#
# Iteration No: 99 ended. Search finished for the next optimal point.
# Time taken: 5.0061
# Function value obtained: 0.1577
# Current minimum: 0.1399
# Iteration No: 100 started. Searching for the next optimal point.
# [0.08236411513496843, 99, 1, 1.0, 1.0, 0.71939176933225, 0.8, 25, 0.1, 25]
#
# Iteration No: 100 ended. Search finished for the next optimal point.
# Time taken: 3.9584
# Function value obtained: 0.1403
# Current minimum: 0.1399
# Iteration No: 101 started. Searching for the next optimal point.
# [0.05076594270117912, 52, 1, 0.05, 0.3995129515586615, 0.7421445236312317, 0.8, 25, 0.1, 25]
#
# Iteration No: 101 ended. Search finished for the next optimal point.
# Time taken: 4.3560
# Function value obtained: 0.1397
# Current minimum: 0.1397
# Iteration No: 102 started. Searching for the next optimal point.
# [0.1, 102, 1, 1.0, 0.21318763804437754, 0.7004782884668606, 0.8306551322640543, 18, 0.010002643908878592, 25]
#
# Iteration No: 102 ended. Search finished for the next optimal point.
# Time taken: 5.0705
# Function value obtained: 0.1443
# Current minimum: 0.1397
# Iteration No: 103 started. Searching for the next optimal point.
# [0.05792837541558216, 58, 1, 0.1650321568373066, 0.1, 0.23159863762217775, 0.8, 25, 0.06646274333761144, 25]
#
# Iteration No: 103 ended. Search finished for the next optimal point.
# Time taken: 4.1755
# Function value obtained: 0.2095
# Current minimum: 0.1397
# Iteration No: 104 started. Searching for the next optimal point.
# [0.04022299584350724, 121, 1, 1.0, 0.2816668774255772, 0.6675879250075383, 1.0, 23, 0.001, 25]
#
# Iteration No: 104 ended. Search finished for the next optimal point.
# Time taken: 5.6659
# Function value obtained: 0.1444
# Current minimum: 0.1397
# Iteration No: 105 started. Searching for the next optimal point.
# [0.05054362286068973, 75, 1, 1.0, 0.27237793734687066, 0.8142738560575266, 0.8, 25, 0.001, 25]
#
# Iteration No: 105 ended. Search finished for the next optimal point.
# Time taken: 5.2423
# Function value obtained: 0.1398
# Current minimum: 0.1397
# Iteration No: 106 started. Searching for the next optimal point.
# [0.06623880493729892, 69, 1, 0.1859645650249268, 1.0, 0.8826420630673728, 0.8, 17, 0.1, 25]
#
# Iteration No: 106 ended. Search finished for the next optimal point.
# Time taken: 4.6432
# Function value obtained: 0.1390
# Current minimum: 0.1390
# Iteration No: 107 started. Searching for the next optimal point.
# [0.07568838290847876, 57, 1, 0.05, 0.1, 0.8294000784642953, 0.8, 25, 0.1, 25]
#
# Iteration No: 107 ended. Search finished for the next optimal point.
# Time taken: 4.4832
# Function value obtained: 0.1395
# Current minimum: 0.1390
# Iteration No: 108 started. Searching for the next optimal point.
# [0.1, 128, 1, 0.5534639812249551, 0.8584081795589663, 0.3001786876172956, 0.8, 22, 0.04032324241166028, 23]
#
# Iteration No: 108 ended. Search finished for the next optimal point.
# Time taken: 4.4772
# Function value obtained: 0.2015
# Current minimum: 0.1390
# Iteration No: 109 started. Searching for the next optimal point.
# [0.1, 105, 1, 0.05, 0.1, 0.7402033092590709, 0.8, 23, 0.08176175293714044, 25]
#
# Iteration No: 109 ended. Search finished for the next optimal point.
# Time taken: 4.4040
# Function value obtained: 0.1400
# Current minimum: 0.1390
# Iteration No: 110 started. Searching for the next optimal point.
# [0.1, 71, 1, 1.0, 0.21310049224295252, 0.1, 0.8, 18, 0.001, 25]
#
# Iteration No: 110 ended. Search finished for the next optimal point.
# Time taken: 4.6299
# Function value obtained: 0.2009
# Current minimum: 0.1390
# Iteration No: 111 started. Searching for the next optimal point.
# [0.06878470511434595, 128, 1, 0.05, 0.1, 0.8729532536332693, 0.8, 25, 0.001, 21]
#
# Iteration No: 111 ended. Search finished for the next optimal point.
# Time taken: 5.4243
# Function value obtained: 0.1421
# Current minimum: 0.1390
# Iteration No: 112 started. Searching for the next optimal point.
# [0.08016673982872968, 62, 1, 0.43145018323560463, 0.1968291618688448, 0.8834576431586826, 0.8, 25, 0.1, 25]
#
# Iteration No: 112 ended. Search finished for the next optimal point.
# Time taken: 4.4772
# Function value obtained: 0.1394
# Current minimum: 0.1390
# Iteration No: 113 started. Searching for the next optimal point.
# [0.032197176611984776, 83, 1, 0.5608057398077366, 0.1, 0.8142877731147229, 0.8533590894269706, 17, 0.1, 10]
#
# Iteration No: 113 ended. Search finished for the next optimal point.
# Time taken: 5.8044
# Function value obtained: 0.1454
# Current minimum: 0.1390
# Iteration No: 114 started. Searching for the next optimal point.
# [0.1, 70, 1, 0.355051405879395, 0.6028096906031535, 0.7302939718544498, 0.8, 20, 0.001, 25]
#
# Iteration No: 114 ended. Search finished for the next optimal point.
# Time taken: 5.4164
# Function value obtained: 0.1427
# Current minimum: 0.1390
# Iteration No: 115 started. Searching for the next optimal point.
# [0.018357998970670107, 128, 1, 0.5551212755890809, 1.0, 0.3826202491126288, 1.0, 21, 0.06133267572052923, 20]
#
# Iteration No: 115 ended. Search finished for the next optimal point.
# Time taken: 5.2133
# Function value obtained: 0.3395
# Current minimum: 0.1390
# Iteration No: 116 started. Searching for the next optimal point.
# [0.04465604022885289, 128, 1, 0.542316140388036, 0.5412891942253362, 0.8562443784264285, 0.8, 17, 0.001, 25]
#
# Iteration No: 116 ended. Search finished for the next optimal point.
# Time taken: 5.6818
# Function value obtained: 0.1411
# Current minimum: 0.1390
# Iteration No: 117 started. Searching for the next optimal point.
# [0.03785724840567104, 39, 100, 0.05, 0.655232766568555, 0.7368628790397821, 0.8, 19, 0.057627135080894315, 25]
#
# Iteration No: 117 ended. Search finished for the next optimal point.
# Time taken: 4.5655
# Function value obtained: 0.1569
# Current minimum: 0.1390
# Iteration No: 118 started. Searching for the next optimal point.
# [0.001, 128, 1, 0.16050043949619477, 0.1, 0.9, 0.8706643024689286, 18, 0.02666784303524974, 10]
#
# Iteration No: 118 ended. Search finished for the next optimal point.
# Time taken: 6.3694
# Function value obtained: 0.9161
# Current minimum: 0.1390
# Iteration No: 119 started. Searching for the next optimal point.
# [0.027953128837795053, 2, 100, 0.45333148909746546, 0.1, 0.3632459361978272, 0.8, 24, 0.001, 20]
#
# Iteration No: 119 ended. Search finished for the next optimal point.
# Time taken: 4.1068
# Function value obtained: 0.4367
# Current minimum: 0.1390
# Iteration No: 120 started. Searching for the next optimal point.
# [0.049857467605699014, 78, 1, 1.0, 0.963672381233262, 0.42527776136304773, 1.0, 17, 0.06493658236051693, 25]
#
# Iteration No: 120 ended. Search finished for the next optimal point.
# Time taken: 4.6291
# Function value obtained: 0.2164
# Current minimum: 0.1390
# Iteration No: 121 started. Searching for the next optimal point.
# [0.1, 105, 1, 1.0, 0.9662713068845864, 0.9, 0.8, 25, 0.1, 25]
#
# Iteration No: 121 ended. Search finished for the next optimal point.
# Time taken: 4.6805
# Function value obtained: 0.1396
# Current minimum: 0.1390
# Iteration No: 122 started. Searching for the next optimal point.
# [0.033940910525411566, 91, 1, 0.05580005806969246, 1.0, 0.7139978814748072, 0.9547182568695025, 19, 0.001, 10]
#
# Iteration No: 122 ended. Search finished for the next optimal point.
# Time taken: 5.9116
# Function value obtained: 0.1454
# Current minimum: 0.1390
# Iteration No: 123 started. Searching for the next optimal point.
# [0.04696448303246742, 53, 1, 0.775178441575179, 0.1, 0.7551232700085925, 1.0, 25, 0.001, 10]
#
# Iteration No: 123 ended. Search finished for the next optimal point.
# Time taken: 5.0491
# Function value obtained: 0.1418
# Current minimum: 0.1390
# Iteration No: 124 started. Searching for the next optimal point.
# [0.07242471928323535, 109, 1, 1.0, 0.7404875350088236, 0.8255350856698729, 0.8, 18, 0.1, 25]
#
# Iteration No: 124 ended. Search finished for the next optimal point.
# Time taken: 5.0051
# Function value obtained: 0.1388
# Current minimum: 0.1388
# Iteration No: 125 started. Searching for the next optimal point.
# [0.056495122149448226, 80, 1, 1.0, 0.1, 0.8309682966132252, 0.8, 17, 0.1, 23]
#
# Iteration No: 125 ended. Search finished for the next optimal point.
# Time taken: 5.1170
# Function value obtained: 0.1396
# Current minimum: 0.1388
# Iteration No: 126 started. Searching for the next optimal point.
# [0.06857276656053428, 52, 1, 1.0, 0.1, 0.751537573939112, 1.0, 25, 0.09714092274069111, 25]
#
# Iteration No: 126 ended. Search finished for the next optimal point.
# Time taken: 4.7772
# Function value obtained: 0.1411
# Current minimum: 0.1388
# Iteration No: 127 started. Searching for the next optimal point.
# [0.1, 29, 1, 0.8145555352184718, 0.46229386485871116, 0.17472752977369874, 1.0, 22, 0.006126318707879592, 12]
#
# Iteration No: 127 ended. Search finished for the next optimal point.
# Time taken: 4.4889
# Function value obtained: 0.1995
# Current minimum: 0.1388
# Iteration No: 128 started. Searching for the next optimal point.
# [0.036576468459248966, 107, 1, 0.18606609354171655, 0.1, 0.6562413909280196, 0.8, 17, 0.093600840148217, 10]
#
# Iteration No: 128 ended. Search finished for the next optimal point.
# Time taken: 6.2420
# Function value obtained: 0.2417
# Current minimum: 0.1388
# Iteration No: 129 started. Searching for the next optimal point.
# [0.04812672374135327, 128, 7, 0.35432696147669906, 0.20602329897876986, 0.6877668039850857, 0.985035488223075, 19, 0.001, 25]
#
# Iteration No: 129 ended. Search finished for the next optimal point.
# Time taken: 8.1438
# Function value obtained: 0.1424
# Current minimum: 0.1388
# Iteration No: 130 started. Searching for the next optimal point.
# [0.1, 53, 1, 0.26542326465352356, 1.0, 0.28655768868401843, 1.0, 25, 0.1, 10]
#
# Iteration No: 130 ended. Search finished for the next optimal point.
# Time taken: 5.6514
# Function value obtained: 0.2062
# Current minimum: 0.1388
# Iteration No: 131 started. Searching for the next optimal point.
# [0.044730609919803675, 128, 1, 1.0, 0.4841597991359107, 0.6842894408445764, 1.0, 19, 0.001, 25]
#
# Iteration No: 131 ended. Search finished for the next optimal point.
# Time taken: 7.2086
# Function value obtained: 0.1431
# Current minimum: 0.1388
# Iteration No: 132 started. Searching for the next optimal point.
# [0.1, 128, 88, 0.7763798341557185, 1.0, 0.5032946699650839, 1.0, 20, 0.001, 25]
#
# Iteration No: 132 ended. Search finished for the next optimal point.
# Time taken: 5.3554
# Function value obtained: 0.1950
# Current minimum: 0.1388
# Iteration No: 133 started. Searching for the next optimal point.
# [0.04509414977666046, 77, 1, 1.0, 1.0, 0.7137409764648042, 1.0, 25, 0.001, 25]
#
# Iteration No: 133 ended. Search finished for the next optimal point.
# Time taken: 6.4077
# Function value obtained: 0.1430
# Current minimum: 0.1388
# Iteration No: 134 started. Searching for the next optimal point.
# [0.05980341542065582, 63, 1, 1.0, 0.1, 0.71672762672972, 0.9056160328654903, 23, 0.001, 25]
#
# Iteration No: 134 ended. Search finished for the next optimal point.
# Time taken: 6.7955
# Function value obtained: 0.1408
# Current minimum: 0.1388
# Iteration No: 135 started. Searching for the next optimal point.
# [0.07030849931277265, 128, 1, 0.05, 0.1, 0.6933723583833928, 0.8, 25, 0.001, 10]
#
# Iteration No: 135 ended. Search finished for the next optimal point.
# Time taken: 8.0185
# Function value obtained: 0.1484
# Current minimum: 0.1388
# Iteration No: 136 started. Searching for the next optimal point.
# [0.1, 68, 1, 1.0, 0.1, 0.8200656001364037, 0.8, 25, 0.001, 25]
#
# Iteration No: 136 ended. Search finished for the next optimal point.
# Time taken: 7.3665
# Function value obtained: 0.1433
# Current minimum: 0.1388
# Iteration No: 137 started. Searching for the next optimal point.
# [0.06979591657389025, 128, 24, 0.05, 0.7554917991447527, 0.16920105403778918, 0.9852248618622907, 17, 0.05245561288816159, 10]
#
# Iteration No: 137 ended. Search finished for the next optimal point.
# Time taken: 6.2402
# Function value obtained: 0.2069
# Current minimum: 0.1388
# Iteration No: 138 started. Searching for the next optimal point.
# [0.1, 2, 1, 1.0, 0.1, 0.5394898307560089, 1.0, 21, 0.00448905752201884, 25]
#
# Iteration No: 138 ended. Search finished for the next optimal point.
# Time taken: 5.7482
# Function value obtained: 0.2222
# Current minimum: 0.1388
# Iteration No: 139 started. Searching for the next optimal point.
# [0.03215101443790382, 128, 1, 0.08142562521201692, 0.30652306058080125, 0.6888512866897494, 0.8097056261304206, 24, 0.001, 25]
#
# Iteration No: 139 ended. Search finished for the next optimal point.
# Time taken: 7.5087
# Function value obtained: 0.1450
# Current minimum: 0.1388
# Iteration No: 140 started. Searching for the next optimal point.
# [0.1, 85, 1, 0.945084406344544, 0.1, 0.8737093342921671, 0.8321929743866807, 24, 0.1, 25]
#
# Iteration No: 140 ended. Search finished for the next optimal point.
# Time taken: 6.8775
# Function value obtained: 0.1404
# Current minimum: 0.1388
# Iteration No: 141 started. Searching for the next optimal point.
# [0.061924780244374415, 67, 1, 0.6246018898284037, 1.0, 0.8756339784744668, 0.8, 25, 0.08764265122324166, 10]
#
# Iteration No: 141 ended. Search finished for the next optimal point.
# Time taken: 6.7052
# Function value obtained: 0.1411
# Current minimum: 0.1388
# Iteration No: 142 started. Searching for the next optimal point.
# [0.04675245561609003, 100, 1, 1.0, 0.5786601617608222, 0.7061554658448723, 0.8589502977864153, 17, 0.001, 25]
#
# Iteration No: 142 ended. Search finished for the next optimal point.
# Time taken: 7.6588
# Function value obtained: 0.1409
# Current minimum: 0.1388
# Iteration No: 143 started. Searching for the next optimal point.
# [0.1, 128, 1, 0.05, 0.1, 0.6470579086439, 0.9296816562339124, 17, 0.001, 25]
#
# Iteration No: 143 ended. Search finished for the next optimal point.
# Time taken: 6.4105
# Function value obtained: 0.2022
# Current minimum: 0.1388
# Iteration No: 144 started. Searching for the next optimal point.
# [0.1, 64, 1, 0.9137234285934703, 1.0, 0.3780441518292056, 0.9723661777818734, 25, 0.1, 16]
#
# Iteration No: 144 ended. Search finished for the next optimal point.
# Time taken: 5.9353
# Function value obtained: 0.2043
# Current minimum: 0.1388
# Iteration No: 145 started. Searching for the next optimal point.
# [0.04616809323954475, 102, 1, 1.0, 1.0, 0.8727363728987573, 0.9480262164071082, 24, 0.1, 25]
#
# Iteration No: 145 ended. Search finished for the next optimal point.
# Time taken: 6.5111
# Function value obtained: 0.1405
# Current minimum: 0.1388
# Iteration No: 146 started. Searching for the next optimal point.
# [0.04291722387616852, 109, 1, 1.0, 0.3903982801473852, 0.7967298019569807, 1.0, 25, 0.001, 25]
#
# Iteration No: 146 ended. Search finished for the next optimal point.
# Time taken: 7.5573
# Function value obtained: 0.1432
# Current minimum: 0.1388
# Iteration No: 147 started. Searching for the next optimal point.
# [0.04727114559330477, 128, 1, 0.7128054502411404, 1.0, 0.47279999702341413, 0.9527805726580107, 25, 0.001, 25]
#
# Iteration No: 147 ended. Search finished for the next optimal point.
# Time taken: 6.4773
# Function value obtained: 0.2189
# Current minimum: 0.1388
# Iteration No: 148 started. Searching for the next optimal point.
# [0.019440112976433072, 2, 1, 0.8770414511422584, 0.3141698174101554, 0.7201475711421818, 1.0, 18, 0.009772209220242252, 19]
#
# Iteration No: 148 ended. Search finished for the next optimal point.
# Time taken: 5.5496
# Function value obtained: 0.4449
# Current minimum: 0.1388
# Iteration No: 149 started. Searching for the next optimal point.
# [0.03962082350989923, 64, 1, 1.0, 0.1, 0.7715320262494498, 1.0, 25, 0.001, 25]
#
# Iteration No: 149 ended. Search finished for the next optimal point.
# Time taken: 7.5095
# Function value obtained: 0.1436
# Current minimum: 0.1388
# Iteration No: 150 started. Searching for the next optimal point.
# [0.043215910171527525, 48, 100, 1.0, 1.0, 0.7815740326967142, 0.8, 23, 0.001, 25]
#
# Iteration No: 150 ended. Search finished for the next optimal point.
# Time taken: 5.7606
# Function value obtained: 0.1538
# Current minimum: 0.1388
# Iteration No: 151 started. Searching for the next optimal point.
# [0.04616713867862282, 128, 1, 0.9748283499755226, 1.0, 0.7345073850497053, 0.8382827611643817, 25, 0.001, 25]
#
# Iteration No: 151 ended. Search finished for the next optimal point.
# Time taken: 7.9136
# Function value obtained: 0.1408
# Current minimum: 0.1388
# Iteration No: 152 started. Searching for the next optimal point.
# [0.08602925040824891, 128, 61, 1.0, 1.0, 0.7813259145772985, 1.0, 25, 0.001, 25]
#
# Iteration No: 152 ended. Search finished for the next optimal point.
# Time taken: 6.3752
# Function value obtained: 0.1428
# Current minimum: 0.1388
# Iteration No: 153 started. Searching for the next optimal point.
# [0.03811654868169159, 128, 11, 0.05, 1.0, 0.7687011256851072, 0.9580233219157872, 24, 0.001, 25]
#
# Iteration No: 153 ended. Search finished for the next optimal point.
# Time taken: 7.1828
# Function value obtained: 0.1430
# Current minimum: 0.1388
# Iteration No: 154 started. Searching for the next optimal point.
# [0.03588337984094904, 87, 1, 1.0, 0.1, 0.7636365237545696, 1.0, 17, 0.001, 25]
#
# Iteration No: 154 ended. Search finished for the next optimal point.
# Time taken: 7.6436
# Function value obtained: 0.1455
# Current minimum: 0.1388
# Iteration No: 155 started. Searching for the next optimal point.
# [0.05287458286636793, 128, 35, 0.05, 0.21634166304952113, 0.726976532482944, 0.8217395968024079, 25, 0.001, 25]
#
# Iteration No: 155 ended. Search finished for the next optimal point.
# Time taken: 7.3434
# Function value obtained: 0.1401
# Current minimum: 0.1388
# Iteration No: 156 started. Searching for the next optimal point.
# [0.07603222162635677, 128, 1, 1.0, 0.1, 0.9, 0.8, 24, 0.1, 25]
#
# Iteration No: 156 ended. Search finished for the next optimal point.
# Time taken: 6.8958
# Function value obtained: 0.1389
# Current minimum: 0.1388
# Iteration No: 157 started. Searching for the next optimal point.
# [0.0813762236308479, 83, 1, 0.5198377051896688, 0.1, 0.7653319663786861, 0.8856946147321272, 25, 0.1, 25]
#
# Iteration No: 157 ended. Search finished for the next optimal point.
# Time taken: 7.1204
# Function value obtained: 0.1400
# Current minimum: 0.1388
# ...
# Time taken: 3.9916
# Function value obtained: 0.1798
# Current minimum: 0.1609
# Iteration No: 144 started. Searching for the next optimal point.
# [0.1, 128, 25, 1.0, 0.282915992789648, 0.9, 0.8, 25, 0.001, 25]
#
# Iteration No: 144 ended. Search finished for the next optimal point.
# Time taken: 4.0352
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 145 started. Searching for the next optimal point.
# [0.1, 59, 9, 1.0, 0.1, 0.9, 0.8, 25, 0.001, 25]
#
# Iteration No: 145 ended. Search finished for the next optimal point.
# Time taken: 4.2249
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 146 started. Searching for the next optimal point.
# [0.1, 128, 27, 1.0, 0.1, 0.9, 0.8124669900429872, 25, 0.001, 25]
#
# Iteration No: 146 ended. Search finished for the next optimal point.
# Time taken: 4.0666
# Function value obtained: 0.1621
# Current minimum: 0.1609
# Iteration No: 147 started. Searching for the next optimal point.
# [0.1, 88, 22, 1.0, 0.7918821951944062, 0.9, 0.8, 25, 0.001, 25]
#
# Iteration No: 147 ended. Search finished for the next optimal point.
# Time taken: 4.3369
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 148 started. Searching for the next optimal point.
# [0.1, 59, 9, 1.0, 0.1, 0.9, 0.8, 25, 0.001, 25]
# /usr/local/lib/python3.7/dist-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Iteration No: 148 ended. Search finished for the next optimal point.
# Time taken: 4.1382
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 149 started. Searching for the next optimal point.
# [0.1, 91, 19, 1.0, 0.1, 0.9, 0.8, 17, 0.001, 25]
#
# Iteration No: 149 ended. Search finished for the next optimal point.
# Time taken: 4.1646
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 150 started. Searching for the next optimal point.
# [0.1, 128, 28, 1.0, 1.0, 0.9, 0.887311707308095, 25, 0.001, 25]
#
# Iteration No: 150 ended. Search finished for the next optimal point.
# Time taken: 4.3070
# Function value obtained: 0.1640
# Current minimum: 0.1609
# Iteration No: 151 started. Searching for the next optimal point.
# [0.04075530988304775, 2, 29, 0.7570588139673861, 0.8832436998828246, 0.4348096617543088, 0.8012791493816366, 21, 0.004929707296495226, 10]
#
# Iteration No: 151 ended. Search finished for the next optimal point.
# Time taken: 4.4743
# Function value obtained: 0.2207
# Current minimum: 0.1609
# Iteration No: 152 started. Searching for the next optimal point.
# [0.03903143806938016, 43, 31, 1.0, 0.1, 0.9, 1.0, 17, 0.006323021373355123, 10]
#
# Iteration No: 152 ended. Search finished for the next optimal point.
# Time taken: 5.1613
# Function value obtained: 0.1732
# Current minimum: 0.1609
# Iteration No: 153 started. Searching for the next optimal point.
# [0.059568317892891215, 55, 23, 1.0, 0.1, 0.9, 0.8883064863775878, 17, 0.001, 25]
#
# Iteration No: 153 ended. Search finished for the next optimal point.
# Time taken: 4.7884
# Function value obtained: 0.1644
# Current minimum: 0.1609
# Iteration No: 154 started. Searching for the next optimal point.
# [0.1, 29, 20, 1.0, 0.1, 0.9, 0.8, 20, 0.001, 25]
#
# Iteration No: 154 ended. Search finished for the next optimal point.
# Time taken: 4.8481
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 155 started. Searching for the next optimal point.
# [0.1, 26, 21, 1.0, 0.1, 0.1, 0.8827159995180441, 18, 0.004791804870950416, 25]
#
# Iteration No: 155 ended. Search finished for the next optimal point.
# Time taken: 4.4941
# Function value obtained: 0.1661
# Current minimum: 0.1609
# Iteration No: 156 started. Searching for the next optimal point.
# [0.07625430408212504, 48, 18, 1.0, 0.1, 0.9, 0.8, 23, 0.001, 25]
#
# Iteration No: 156 ended. Search finished for the next optimal point.
# Time taken: 4.9055
# Function value obtained: 0.1639
# Current minimum: 0.1609
# Iteration No: 157 started. Searching for the next optimal point.
# [0.1, 128, 16, 1.0, 0.1, 0.9, 0.8, 25, 0.001, 25]
#
# Iteration No: 157 ended. Search finished for the next optimal point.
# Time taken: 4.4735
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 158 started. Searching for the next optimal point.
# [0.1, 108, 17, 1.0, 0.1, 0.9, 0.8, 25, 0.001, 25]
#
# Iteration No: 158 ended. Search finished for the next optimal point.
# Time taken: 4.9980
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 159 started. Searching for the next optimal point.
# [0.1, 108, 21, 1.0, 0.1, 0.9, 0.8, 25, 0.001, 25]
#
# Iteration No: 159 ended. Search finished for the next optimal point.
# Time taken: 5.0485
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 160 started. Searching for the next optimal point.
# [0.1, 24, 13, 0.7878082761833357, 0.1, 0.9, 0.8, 23, 0.001, 18]
#
# Iteration No: 160 ended. Search finished for the next optimal point.
# Time taken: 5.2098
# Function value obtained: 0.1630
# Current minimum: 0.1609
# Iteration No: 161 started. Searching for the next optimal point.
# [0.1, 128, 19, 0.05, 0.6441776786579574, 0.9, 0.8, 25, 0.001, 25]
#
# Iteration No: 161 ended. Search finished for the next optimal point.
# Time taken: 5.1735
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 162 started. Searching for the next optimal point.
# [0.1, 31, 9, 1.0, 0.4086812254943467, 0.9, 0.8, 17, 0.001, 25]
#
# Iteration No: 162 ended. Search finished for the next optimal point.
# Time taken: 5.4182
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 163 started. Searching for the next optimal point.
# [0.1, 90, 1, 0.05, 0.1, 0.9, 0.8, 25, 0.001, 25]
#
# Iteration No: 163 ended. Search finished for the next optimal point.
# Time taken: 5.3655
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 164 started. Searching for the next optimal point.
# [0.052365505808460104, 65, 24, 1.0, 0.1, 0.9, 0.8858911626435623, 25, 0.001, 25]
#
# Iteration No: 164 ended. Search finished for the next optimal point.
# Time taken: 6.0187
# Function value obtained: 0.1646
# Current minimum: 0.1609
# Iteration No: 165 started. Searching for the next optimal point.
# [0.1, 93, 1, 1.0, 0.1, 0.9, 0.8, 25, 0.001, 25]
#
# Iteration No: 165 ended. Search finished for the next optimal point.
# Time taken: 5.5328
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 166 started. Searching for the next optimal point.
# [0.1, 76, 1, 0.05, 0.1, 0.9, 0.8, 25, 0.001, 25]
#
# Iteration No: 166 ended. Search finished for the next optimal point.
# Time taken: 5.6387
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 167 started. Searching for the next optimal point.
# [0.1, 103, 11, 1.0, 0.1, 0.9, 0.8, 25, 0.001, 25]
#
# Iteration No: 167 ended. Search finished for the next optimal point.
# Time taken: 5.6593
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 168 started. Searching for the next optimal point.
# [0.1, 103, 11, 0.5749438396013785, 0.1, 0.9, 0.8, 17, 0.001, 25]
#
# Iteration No: 168 ended. Search finished for the next optimal point.
# Time taken: 6.6068
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 169 started. Searching for the next optimal point.
# [0.1, 83, 1, 1.0, 0.7215604673576035, 0.9, 0.8, 25, 0.1, 25]
#
# Iteration No: 169 ended. Search finished for the next optimal point.
# Time taken: 6.8126
# Function value obtained: 0.1654
# Current minimum: 0.1609
# Iteration No: 170 started. Searching for the next optimal point.
# [0.1, 110, 18, 0.05, 0.1, 0.9, 0.8, 20, 0.001, 25]
#
# Iteration No: 170 ended. Search finished for the next optimal point.
# Time taken: 6.0324
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 171 started. Searching for the next optimal point.
# [0.1, 110, 18, 0.05, 1.0, 0.9, 0.8, 25, 0.001, 25]
#
# Iteration No: 171 ended. Search finished for the next optimal point.
# Time taken: 6.4534
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 172 started. Searching for the next optimal point.
# [0.1, 128, 13, 1.0, 0.1, 0.9, 0.8, 25, 0.001, 25]
#
# Iteration No: 172 ended. Search finished for the next optimal point.
# Time taken: 6.1940
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 173 started. Searching for the next optimal point.
# [0.1, 22, 19, 0.929788993603291, 0.20694724369291023, 0.9, 0.8, 17, 0.001, 20]
#
# Iteration No: 173 ended. Search finished for the next optimal point.
# Time taken: 5.9170
# Function value obtained: 0.1665
# Current minimum: 0.1609
# Iteration No: 174 started. Searching for the next optimal point.
# [0.1, 128, 1, 1.0, 0.1, 0.9, 0.8, 25, 0.001, 25]
#
# Iteration No: 174 ended. Search finished for the next optimal point.
# Time taken: 6.4231
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 175 started. Searching for the next optimal point.
# [0.03789035742025898, 89, 15, 1.0, 0.1, 0.9, 0.8, 25, 0.001, 10]
#
# Iteration No: 175 ended. Search finished for the next optimal point.
# Time taken: 6.6596
# Function value obtained: 0.1688
# Current minimum: 0.1609
# Iteration No: 176 started. Searching for the next optimal point.
# [0.1, 128, 12, 0.05, 1.0, 0.9, 0.8, 22, 0.001, 25]
#
# Iteration No: 176 ended. Search finished for the next optimal point.
# Time taken: 6.4445
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 177 started. Searching for the next optimal point.
# [0.1, 111, 10, 0.2220158760710304, 0.1, 0.9, 0.8, 17, 0.001, 25]
#
# Iteration No: 177 ended. Search finished for the next optimal point.
# Time taken: 6.1384
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 178 started. Searching for the next optimal point.
# [0.1, 128, 1, 0.05, 0.1, 0.9, 0.8, 17, 0.001, 25]
#
# Iteration No: 178 ended. Search finished for the next optimal point.
# Time taken: 6.1587
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 179 started. Searching for the next optimal point.
# [0.08169862813079609, 128, 9, 0.7895979322653599, 0.1, 0.9, 0.8, 25, 0.001, 25]
#
# Iteration No: 179 ended. Search finished for the next optimal point.
# Time taken: 6.5444
# Function value obtained: 0.1633
# Current minimum: 0.1609
# Iteration No: 180 started. Searching for the next optimal point.
# [0.1, 115, 10, 1.0, 0.9877468119585359, 0.9, 0.8, 19, 0.001, 25]
#
# Iteration No: 180 ended. Search finished for the next optimal point.
# Time taken: 6.0622
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 181 started. Searching for the next optimal point.
# [0.1, 128, 15, 1.0, 1.0, 0.9, 0.8, 25, 0.001, 25]
#
# Iteration No: 181 ended. Search finished for the next optimal point.
# Time taken: 6.3621
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 182 started. Searching for the next optimal point.
# [0.1, 108, 23, 1.0, 0.1, 0.9, 0.8721465760526728, 25, 0.001, 25]
#
# Iteration No: 182 ended. Search finished for the next optimal point.
# Time taken: 6.5979
# Function value obtained: 0.1639
# Current minimum: 0.1609
# Iteration No: 183 started. Searching for the next optimal point.
# [0.1, 128, 15, 0.3780188754632003, 0.1, 0.9, 0.8, 25, 0.001, 25]
#
# Iteration No: 183 ended. Search finished for the next optimal point.
# Time taken: 6.6822
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 184 started. Searching for the next optimal point.
# [0.1, 33, 31, 1.0, 0.7443631847818264, 0.1, 1.0, 23, 0.001, 10]
#
# Iteration No: 184 ended. Search finished for the next optimal point.
# Time taken: 6.8380
# Function value obtained: 0.1648
# Current minimum: 0.1609
# Iteration No: 185 started. Searching for the next optimal point.
# [0.06240450100262404, 61, 26, 1.0, 0.1, 0.9, 0.8743993197664308, 19, 0.001, 19]
#
# Iteration No: 185 ended. Search finished for the next optimal point.
# Time taken: 6.9770
# Function value obtained: 0.1644
# Current minimum: 0.1609
# Iteration No: 186 started. Searching for the next optimal point.
# [0.1, 128, 19, 1.0, 0.1, 0.9, 0.8160159781210642, 17, 0.001, 25]
#
# Iteration No: 186 ended. Search finished for the next optimal point.
# Time taken: 7.5127
# Function value obtained: 0.1635
# Current minimum: 0.1609
# Iteration No: 187 started. Searching for the next optimal point.
# [0.1, 34, 1, 1.0, 0.46076059810231396, 0.9, 0.8, 17, 0.1, 25]
#
# Iteration No: 187 ended. Search finished for the next optimal point.
# Time taken: 6.7379
# Function value obtained: 0.1654
# Current minimum: 0.1609
# Iteration No: 188 started. Searching for the next optimal point.
# [0.06188943728792153, 64, 18, 1.0, 0.1, 0.9, 0.8, 25, 0.001, 25]
#
# Iteration No: 188 ended. Search finished for the next optimal point.
# Time taken: 7.4814
# Function value obtained: 0.1631
# Current minimum: 0.1609
# Iteration No: 189 started. Searching for the next optimal point.
# [0.1, 128, 1, 1.0, 1.0, 0.9, 0.8, 25, 0.001, 25]
#
# Iteration No: 189 ended. Search finished for the next optimal point.
# Time taken: 6.9345
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 190 started. Searching for the next optimal point.
# [0.1, 105, 1, 1.0, 0.1, 0.9, 0.8, 17, 0.001, 25]
#
# Iteration No: 190 ended. Search finished for the next optimal point.
# Time taken: 6.9758
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 191 started. Searching for the next optimal point.
# [0.06615924474287856, 128, 30, 1.0, 0.16009455691401742, 0.9, 1.0, 18, 0.001, 18]
#
# Iteration No: 191 ended. Search finished for the next optimal point.
# Time taken: 7.1649
# Function value obtained: 0.1670
# Current minimum: 0.1609
# Iteration No: 192 started. Searching for the next optimal point.
# [0.1, 110, 1, 0.05, 0.1, 0.9, 0.8, 25, 0.001, 25]
#
# Iteration No: 192 ended. Search finished for the next optimal point.
# Time taken: 6.9865
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 193 started. Searching for the next optimal point.
# [0.1, 128, 1, 1.0, 0.1, 0.9, 0.8, 17, 0.001, 25]
#
# Iteration No: 193 ended. Search finished for the next optimal point.
# Time taken: 7.4232
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 194 started. Searching for the next optimal point.
# [0.05656427185410124, 65, 16, 0.5263760286657829, 0.1, 0.9, 0.8, 17, 0.0043107791463064295, 25]
#
# Iteration No: 194 ended. Search finished for the next optimal point.
# Time taken: 7.2145
# Function value obtained: 0.1635
# Current minimum: 0.1609
# Iteration No: 195 started. Searching for the next optimal point.
# [0.1, 128, 1, 1.0, 1.0, 0.9, 0.8, 17, 0.001, 25]
#
# Iteration No: 195 ended. Search finished for the next optimal point.
# Time taken: 7.1197
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 196 started. Searching for the next optimal point.
# [0.1, 128, 1, 1.0, 0.1, 0.9, 0.8, 25, 0.001, 25]
# /usr/local/lib/python3.7/dist-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Iteration No: 196 ended. Search finished for the next optimal point.
# Time taken: 7.5483
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 197 started. Searching for the next optimal point.
# [0.1, 103, 1, 1.0, 1.0, 0.9, 0.8, 17, 0.001, 25]
#
# Iteration No: 197 ended. Search finished for the next optimal point.
# Time taken: 7.3758
# Function value obtained: 0.1612
# Current minimum: 0.1609
# Iteration No: 198 started. Searching for the next optimal point.
# [0.08556158891768433, 128, 1, 0.05, 0.1, 0.9, 0.8, 25, 0.001, 25]
#
# Iteration No: 198 ended. Search finished for the next optimal point.
# Time taken: 7.6624
# Function value obtained: 0.1632
# Current minimum: 0.1609
# Iteration No: 199 started. Searching for the next optimal point.
# [0.1, 42, 23, 0.6042570111555987, 0.1, 0.9, 0.8, 25, 0.001, 22]
#
# Iteration No: 199 ended. Search finished for the next optimal point.
# Time taken: 7.8009
# Function value obtained: 0.1636
# Current minimum: 0.1609
# Iteration No: 200 started. Searching for the next optimal point.
# [0.1, 113, 1, 0.05, 1.0, 0.9, 0.8, 25, 0.001, 25]
#
# Iteration No: 200 ended. Search finished for the next optimal point.
# Time taken: 7.2375
# Function value obtained: 0.1612
# Current minimum: 0.1609

# %% [markdown]
# ### Modelagem - Terrenos

# %%
import pandas as pd

data_terrenos = pd.read_csv("data/html_terrenos/data_terrenos.csv")
data_terrenos = data_terrenos[["municipio", "area", "lat", "lng", "valor"]]

# %%
data_terrenos = data_terrenos.drop_duplicates()
data_terrenos["municipio"] = data_terrenos["municipio"].str.lower()
data_terrenos["area"] = data_terrenos["area"].str.replace("\n", "")
data_terrenos["valor"] = data_terrenos["valor"].str.replace("\n", "")
data_terrenos = data_terrenos[~data_terrenos["area"].str.contains("-")]
data_terrenos = data_terrenos[~data_terrenos["valor"].str.contains("A partir de ")]
data_terrenos = data_terrenos[~data_terrenos["valor"].str.contains("Mês")]
data_terrenos = data_terrenos[~data_terrenos["valor"].str.contains("Sob Consulta")]
data_terrenos = data_terrenos[~data_terrenos["valor"].str.contains("Dia")]
data_terrenos = data_terrenos[~data_terrenos["valor"].str.contains("Semana")]
data_terrenos["valor"] = data_terrenos["valor"].str.replace(".", "").str.replace("R", "").str.replace('[\$,]', '', regex=True).astype(float)
data_terrenos["area"] = data_terrenos["area"].astype(float)

# %%
desempenho_mdl = pd.DataFrame(columns = ["mun", "msle"])

# %%
from skopt import gp_minimize
from lightgbm import LGBMRegressor
import pandas as pd
import numpy as np
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import mean_squared_log_error
import pickle

for mun in data_terrenos["municipio"].unique():

  print(f"Treinando modelo para {mun}")

  train = data_terrenos[data_terrenos["municipio"]==mun]
  train['valor'] = train['valor'].map(lambda x: math.log(x))

  X = train.drop(["valor", "municipio"], 1)
  y = train["valor"]

  def treinar_modelo(params):
        learning_rate = params[0]
        num_leaves = params[1]
        min_child_samples = params[2]
        subsample = params[3]
        colsample_bytree = params[4]
        feature_fraction = params[5]
        bagging_fraction = params[6]
        max_depth = params[7]
        min_split_gain = params[8]
        min_child_weight = params[9]
        
        print(params, '\n')

        mdl = LGBMRegressor(learning_rate=learning_rate, num_leaves=num_leaves, min_child_samples=min_child_samples,
                        subsample=subsample, colsample_bytree=colsample_bytree, feature_fraction=feature_fraction, 
                        bagging_fraction=bagging_fraction, max_depth=max_depth, min_split_gain=min_split_gain, 
                        min_child_weight=min_child_weight, random_state=0, subsample_freq=1, n_estimators=100)
        
        yhat = cross_val_predict(mdl, X, y, cv = 10)
        yhat_reais = np.exp(yhat)
        y_reais = np.exp(y)
        #yhat_reais = yhat
        #y_reais = y

        return mean_squared_log_error(y_reais, yhat_reais)


  space = [(1e-3, 1e-1, 'log-uniform'), #learning_rate
          (2, 128), # num_leaves
          (1, 100), # min_child_samples
          (0.05, 1.0), # subsamples
          (0.1, 1.0), # colsample_bytree
          (0.1, 0.9), # feature_fraction
          (0.8, 1), # bagging_fraction 
          (17, 25), # max_depth
          (0.001, 0.1), # min_split_gain
          (10, 25) # min_child_weight
          ] 

  resultados_gp = gp_minimize(treinar_modelo, space, random_state=1, verbose=1, n_calls=200, n_random_starts=10)

  ### append df desempenho

  desempenho_mdl = desempenho_mdl.append({"mun": mun, "msle": resultados_gp.fun}, ignore_index=True)

  ### saved model

  mdl = LGBMRegressor(learning_rate=resultados_gp.x[0], num_leaves=resultados_gp.x[1], min_child_samples=resultados_gp.x[2],
                      subsample=resultados_gp.x[3], colsample_bytree=resultados_gp.x[4], feature_fraction=resultados_gp.x[5],
                      bagging_fraction=resultados_gp.x[6], max_depth=resultados_gp.x[7], min_split_gain=resultados_gp.x[8], min_child_weight=resultados_gp.x[9],
                      random_state=0, subsample_freq=1, n_estimators=100)

  pkl_filename = f"models/terrenos/mdl_terrenos_{mun}.pkl"
  with open(pkl_filename, 'wb') as file:
      pickle.dump(mdl, file)


desempenho_mdl.to_csv("models/terrenos/desempenho_mdl.csv", index=False)
# Out:
# Treinando modelo para sãopaulo
# Iteration No: 1 started. Evaluating function at random point.
# [0.09871192514273254, 120, 14, 0.9990884895579377, 0.3124800792567785, 0.417264581836821, 0.8775821482324015, 22, 0.09361836800979718, 23]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 0.8622
# Function value obtained: 0.1997
# Current minimum: 0.1997
# Iteration No: 2 started. Evaluating function at random point.
# [0.004232013397179603, 68, 45, 0.2680983530433343, 0.5809725180523154, 0.8311696196633865, 0.8914409615973977, 20, 0.09397365115293897, 22]
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 1.0528
# Function value obtained: 0.6038
# Current minimum: 0.1997
# Iteration No: 3 started. Evaluating function at random point.
# [0.027035912483147396, 103, 10, 0.5422449214947946, 0.8785182267810853, 0.7633175258937135, 0.9659206718788368, 19, 0.006865076928854784, 20]
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 2.2851
# Function value obtained: 0.1544
# Current minimum: 0.1544
# Iteration No: 4 started. Evaluating function at random point.
# [0.01535080081765723, 87, 42, 0.23767335308554222, 0.3606666764912312, 0.21369610837996558, 0.9566628945389772, 20, 0.0043829598073980664, 19]
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 0.9311
# Function value obtained: 0.3801
# Current minimum: 0.1544
# Iteration No: 5 started. Evaluating function at random point.
# [0.02095421812724112, 40, 45, 0.2610183201586061, 0.16602775456833962, 0.47539082115051456, 0.8192344520890924, 24, 0.01282955633009097, 18]
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 0.7977
# Function value obtained: 0.3067
# Current minimum: 0.1544
# Iteration No: 6 started. Evaluating function at random point.
# [0.0014697585967435188, 118, 91, 0.3339836065992303, 0.6259502086641363, 0.5527296219713546, 0.9227876635592112, 25, 0.026836918981940135, 13]
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 0.5808
# Function value obtained: 0.9344
# Current minimum: 0.1544
# Iteration No: 7 started. Evaluating function at random point.
# [0.011665328715255016, 122, 50, 0.5635704833824619, 0.7889365939967841, 0.1362765828597226, 0.827993223838343, 23, 0.003950334460056934, 23]
#
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 0.7971
# Function value obtained: 0.4593
# Current minimum: 0.1544
# Iteration No: 8 started. Evaluating function at random point.
# [0.012066362801915467, 58, 89, 0.40870512409354, 0.5845822248519866, 0.6218391056508338, 0.8722522040423242, 22, 0.06414581192190798, 12]
#
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 0.5509
# Function value obtained: 0.4529
# Current minimum: 0.1544
# Iteration No: 9 started. Evaluating function at random point.
# [0.024010940718920456, 84, 36, 0.775071400079366, 0.4208785512022495, 0.7022306825404836, 0.9762683659268023, 17, 0.050312797893195434, 11]
#
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 1.2206
# Function value obtained: 0.1640
# Current minimum: 0.1544
# Iteration No: 10 started. Evaluating function at random point.
# [0.03748892170175449, 10, 36, 0.9447451013157516, 0.4418229580918275, 0.7103360587559912, 0.9543189996088736, 19, 0.07750117553098015, 12]
#
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 1.4037
# Function value obtained: 0.1552
# Current minimum: 0.1544
# Iteration No: 11 started. Searching for the next optimal point.
# [0.02898210419532271, 125, 2, 0.7999055320121816, 0.9714441738545149, 0.7480970898356384, 1.0, 17, 0.013552394259097246, 19]
#
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 3.2663
# Function value obtained: 0.1526
# Current minimum: 0.1526
# Iteration No: 12 started. Searching for the next optimal point.
# [0.061845047519076574, 128, 22, 1.0, 0.42765160112249023, 0.9, 0.8, 17, 0.1, 10]
#
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 2.0310
# Function value obtained: 0.1405
# Current minimum: 0.1405
# Iteration No: 13 started. Searching for the next optimal point.
# [0.1, 2, 28, 0.05, 0.1, 0.9, 1.0, 17, 0.1, 10]
#
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 1.1491
# Function value obtained: 0.2239
# Current minimum: 0.1405
# Iteration No: 14 started. Searching for the next optimal point.
# [0.035505216403061875, 128, 15, 1.0, 0.7726385705583055, 0.9, 0.929566276934318, 17, 0.058670129495749755, 13]
#
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 3.0325
# Function value obtained: 0.1473
# Current minimum: 0.1405
# Iteration No: 15 started. Searching for the next optimal point.
# [0.1, 128, 100, 1.0, 1.0, 0.9, 1.0, 17, 0.001, 25]
#
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 1.4971
# Function value obtained: 0.1459
# Current minimum: 0.1405
# Iteration No: 16 started. Searching for the next optimal point.
# [0.03630028226051168, 26, 100, 0.5528767786741229, 0.8975264279000761, 0.9, 1.0, 17, 0.06269042247775442, 10]
#
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 1.6079
# Function value obtained: 0.1538
# Current minimum: 0.1405
# Iteration No: 17 started. Searching for the next optimal point.
# [0.07630319833900971, 113, 100, 1.0, 0.8382578765766964, 0.255509316603302, 0.8, 17, 0.001, 25]
#
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 1.4134
# Function value obtained: 0.1973
# Current minimum: 0.1405
# Iteration No: 18 started. Searching for the next optimal point.
# [0.05066005811950772, 128, 20, 1.0, 1.0, 0.9, 0.8282458069030402, 25, 0.001, 20]
#
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 2.8010
# Function value obtained: 0.1426
# Current minimum: 0.1405
# Iteration No: 19 started. Searching for the next optimal point.
# [0.06517946644234535, 75, 1, 1.0, 0.1, 0.9, 1.0, 24, 0.08823519562291543, 10]
#
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 2.2263
# Function value obtained: 0.1431
# Current minimum: 0.1405
# Iteration No: 20 started. Searching for the next optimal point.
# [0.1, 128, 100, 0.7309855784370417, 1.0, 0.9, 0.9320502488441436, 17, 0.001, 25]
#
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 1.6388
# Function value obtained: 0.1465
# Current minimum: 0.1405
# Iteration No: 21 started. Searching for the next optimal point.
# [0.044779959137892934, 38, 43, 0.675024203735335, 0.1, 0.9, 0.9757158586439045, 17, 0.06608616306375324, 10]
#
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 2.2354
# Function value obtained: 0.1426
# Current minimum: 0.1405
# Iteration No: 22 started. Searching for the next optimal point.
# [0.09511731351638641, 128, 1, 1.0, 1.0, 0.9, 0.8056393136557559, 25, 0.1, 25]
#
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 1.9618
# Function value obtained: 0.1414
# Current minimum: 0.1405
# Iteration No: 23 started. Searching for the next optimal point.
# [0.07284942016163043, 13, 1, 0.8460808950045939, 1.0, 0.9, 0.8, 25, 0.001, 25]
#
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 1.5440
# Function value obtained: 0.1416
# Current minimum: 0.1405
# Iteration No: 24 started. Searching for the next optimal point.
# [0.05244633791845039, 128, 1, 0.4842295135830013, 1.0, 0.9, 0.8, 25, 0.1, 24]
#
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 2.2506
# Function value obtained: 0.1405
# Current minimum: 0.1405
# Iteration No: 25 started. Searching for the next optimal point.
# [0.056262713404799665, 128, 33, 0.8538849519096378, 0.48066162848401883, 0.9, 0.8686205971568626, 25, 0.1, 25]
#
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 2.0080
# Function value obtained: 0.1403
# Current minimum: 0.1403
# Iteration No: 26 started. Searching for the next optimal point.
# [0.056493574952270725, 14, 1, 0.7833465334143058, 0.9403321447891785, 0.9, 0.8, 25, 0.001, 25]
#
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 1.6398
# Function value obtained: 0.1430
# Current minimum: 0.1403
# Iteration No: 27 started. Searching for the next optimal point.
# [0.06783851502239217, 128, 1, 1.0, 1.0, 0.9, 0.9865837997785885, 21, 0.09039065189277835, 12]
#
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 2.7226
# Function value obtained: 0.1460
# Current minimum: 0.1403
# Iteration No: 28 started. Searching for the next optimal point.
# [0.07184324492041463, 2, 66, 0.9743087569776031, 0.9685422569666411, 0.1, 0.8, 25, 0.001, 25]
#
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 1.2698
# Function value obtained: 0.2526
# Current minimum: 0.1403
# Iteration No: 29 started. Searching for the next optimal point.
# [0.038438565550491736, 128, 1, 0.7189871491805272, 0.1, 0.9, 0.8, 22, 0.013168299468293076, 25]
#
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 2.6830
# Function value obtained: 0.1431
# Current minimum: 0.1403
# Iteration No: 30 started. Searching for the next optimal point.
# [0.05054109897839377, 122, 100, 1.0, 1.0, 0.9, 0.8, 17, 0.1, 18]
#
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 1.6254
# Function value obtained: 0.1519
# Current minimum: 0.1403
# Iteration No: 31 started. Searching for the next optimal point.
# [0.1, 128, 1, 0.9236481415154548, 1.0, 0.63865297531663, 0.8, 25, 0.001, 25]
#
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 2.3263
# Function value obtained: 0.2000
# Current minimum: 0.1403
# Iteration No: 32 started. Searching for the next optimal point.
# [0.08861104307139842, 128, 1, 1.0, 0.1, 0.9, 0.8, 17, 0.1, 25]
#
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 2.2094
# Function value obtained: 0.1411
# Current minimum: 0.1403
# Iteration No: 33 started. Searching for the next optimal point.
# [0.04223473049662678, 128, 1, 0.05, 0.1, 0.9, 0.8, 17, 0.001, 25]
#
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 2.8505
# Function value obtained: 0.1420
# Current minimum: 0.1403
# Iteration No: 34 started. Searching for the next optimal point.
# [0.05591707710970966, 128, 1, 0.4782483638841323, 1.0, 0.9, 0.8, 17, 0.1, 25]
#
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 2.3737
# Function value obtained: 0.1404
# Current minimum: 0.1403
# Iteration No: 35 started. Searching for the next optimal point.
# [0.0754417111577704, 128, 1, 0.05, 0.1, 0.2715796510095986, 0.8215740017807593, 18, 0.001, 10]
#
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 3.5220
# Function value obtained: 0.2185
# Current minimum: 0.1403
# Iteration No: 36 started. Searching for the next optimal point.
# [0.042927356735639265, 128, 1, 1.0, 0.1, 0.4168933829592246, 0.8150622216565439, 20, 0.001, 10]
#
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 3.5007
# Function value obtained: 0.2343
# Current minimum: 0.1403
# Iteration No: 37 started. Searching for the next optimal point.
# [0.030999569401278928, 128, 1, 0.06736353115465998, 0.1, 0.7947525386851849, 1.0, 24, 0.049703418466461334, 10]
#
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 3.7881
# Function value obtained: 0.1538
# Current minimum: 0.1403
# Iteration No: 38 started. Searching for the next optimal point.
# [0.024005108570491006, 128, 1, 0.761467251701499, 0.7699410411012997, 0.9, 1.0, 19, 0.001, 25]
#
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 3.2857
# Function value obtained: 0.1627
# Current minimum: 0.1403
# Iteration No: 39 started. Searching for the next optimal point.
# [0.04923450142368678, 128, 1, 0.8271819929211848, 0.1, 0.677265825062798, 1.0, 25, 0.001, 25]
#
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 3.1725
# Function value obtained: 0.1428
# Current minimum: 0.1403
# Iteration No: 40 started. Searching for the next optimal point.
# [0.057945623036170166, 128, 1, 1.0, 0.6231733655840332, 0.7922247735606119, 1.0, 25, 0.07724828874151037, 25]
#
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 2.6919
# Function value obtained: 0.1425
# Current minimum: 0.1403
# Iteration No: 41 started. Searching for the next optimal point.
# [0.05362638087036869, 128, 1, 0.13561216549817595, 0.6763957593749726, 0.9, 1.0, 25, 0.01777265125578477, 10]
#
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 3.9985
# Function value obtained: 0.1495
# Current minimum: 0.1403
# Iteration No: 42 started. Searching for the next optimal point.
# [0.1, 128, 100, 1.0, 0.1, 0.1, 0.8, 17, 0.001, 25]
#
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 1.7818
# Function value obtained: 0.1936
# Current minimum: 0.1403
# Iteration No: 43 started. Searching for the next optimal point.
# [0.038414305077014675, 69, 1, 1.0, 0.1, 0.7370159379471782, 1.0, 17, 0.03782843772603288, 25]
#
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 2.9564
# Function value obtained: 0.1449
# Current minimum: 0.1403
# Iteration No: 44 started. Searching for the next optimal point.
# [0.022781416612327385, 128, 1, 1.0, 0.1, 0.9, 0.941883050849751, 17, 0.007960738148713323, 10]
#
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 4.1499
# Function value obtained: 0.1664
# Current minimum: 0.1403
# Iteration No: 45 started. Searching for the next optimal point.
# [0.07113413880051678, 128, 1, 1.0, 0.1, 0.9, 0.8, 25, 0.001, 25]
#
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 3.0457
# Function value obtained: 0.1416
# Current minimum: 0.1403
# Iteration No: 46 started. Searching for the next optimal point.
# [0.05950516970680305, 128, 100, 1.0, 0.1, 0.6228082957215605, 1.0, 23, 0.1, 25]
#
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 1.8072
# Function value obtained: 0.2031
# Current minimum: 0.1403
# Iteration No: 47 started. Searching for the next optimal point.
# [0.03159666145707084, 2, 1, 1.0, 0.1, 0.9, 0.8, 17, 0.1, 25]
#
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 1.7011
# Function value obtained: 0.3436
# Current minimum: 0.1403
# Iteration No: 48 started. Searching for the next optimal point.
# [0.06037657189949448, 20, 16, 0.9717854214142548, 1.0, 0.859454320980344, 0.8414435268009498, 25, 0.001, 22]
#
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 2.0500
# Function value obtained: 0.1406
# Current minimum: 0.1403
# Iteration No: 49 started. Searching for the next optimal point.
# [0.04140585178749801, 30, 78, 0.9955555141541159, 0.4331886379957023, 0.7255401139133554, 0.8464980757251637, 17, 0.1, 25]
#
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 2.1284
# Function value obtained: 0.1499
# Current minimum: 0.1403
# Iteration No: 50 started. Searching for the next optimal point.
# [0.04297510700165675, 15, 100, 1.0, 0.9570221887711402, 0.614646962710056, 1.0, 18, 0.001, 25]
#
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 2.0992
# Function value obtained: 0.2166
# Current minimum: 0.1403
# Iteration No: 51 started. Searching for the next optimal point.
# [0.06365664798385641, 2, 1, 0.9697003821932173, 0.14856072675903315, 0.489293606756216, 0.8, 19, 0.024694706991743358, 25]
#
# Iteration No: 51 ended. Search finished for the next optimal point.
# Time taken: 1.7737
# Function value obtained: 0.2677
# Current minimum: 0.1403
# Iteration No: 52 started. Searching for the next optimal point.
# [0.1, 2, 100, 1.0, 1.0, 0.1, 1.0, 25, 0.1, 25]
#
# Iteration No: 52 ended. Search finished for the next optimal point.
# Time taken: 1.7092
# Function value obtained: 0.2231
# Current minimum: 0.1403
# Iteration No: 53 started. Searching for the next optimal point.
# [0.03859577822794733, 73, 44, 1.0, 0.603900626620376, 0.7468212659526535, 0.8, 21, 0.1, 25]
#
# Iteration No: 53 ended. Search finished for the next optimal point.
# Time taken: 2.3953
# Function value obtained: 0.1454
# Current minimum: 0.1403
# Iteration No: 54 started. Searching for the next optimal point.
# [0.05181111598526778, 36, 100, 1.0, 0.6034115612440375, 0.9, 0.8, 17, 0.1, 25]
#
# Iteration No: 54 ended. Search finished for the next optimal point.
# Time taken: 2.2678
# Function value obtained: 0.1517
# Current minimum: 0.1403
# Iteration No: 55 started. Searching for the next optimal point.
# [0.021528851110966144, 128, 100, 1.0, 0.13371269308799633, 0.9, 0.8, 17, 0.001, 25]
#
# Iteration No: 55 ended. Search finished for the next optimal point.
# Time taken: 2.2883
# Function value obtained: 0.1934
# Current minimum: 0.1403
# Iteration No: 56 started. Searching for the next optimal point.
# [0.1, 64, 1, 1.0, 1.0, 0.1, 0.8, 17, 0.1, 25]
#
# Iteration No: 56 ended. Search finished for the next optimal point.
# Time taken: 2.3108
# Function value obtained: 0.1981
# Current minimum: 0.1403
# Iteration No: 57 started. Searching for the next optimal point.
# [0.041447345158435275, 128, 1, 0.05, 0.2389166538444892, 0.6864567080658329, 0.8, 22, 0.001, 17]
#
# Iteration No: 57 ended. Search finished for the next optimal point.
# Time taken: 3.8171
# Function value obtained: 0.1435
# Current minimum: 0.1403
# Iteration No: 58 started. Searching for the next optimal point.
# [0.044211699494838906, 128, 1, 1.0, 0.1, 0.7423370347150098, 0.9226409862399214, 25, 0.021022170448414913, 25]
#
# Iteration No: 58 ended. Search finished for the next optimal point.
# Time taken: 3.4971
# Function value obtained: 0.1425
# Current minimum: 0.1403
# Iteration No: 59 started. Searching for the next optimal point.
# [0.06251831495360961, 36, 1, 0.7429192862847342, 0.9084136867764045, 0.9, 0.8, 21, 0.09235368812099862, 25]
#
# Iteration No: 59 ended. Search finished for the next optimal point.
# Time taken: 2.6270
# Function value obtained: 0.1405
# Current minimum: 0.1403
# Iteration No: 60 started. Searching for the next optimal point.
# [0.042592771894698116, 60, 78, 1.0, 0.1, 0.9, 0.8, 18, 0.001, 25]
#
# Iteration No: 60 ended. Search finished for the next optimal point.
# Time taken: 2.2791
# Function value obtained: 0.1495
# Current minimum: 0.1403
# Iteration No: 61 started. Searching for the next optimal point.
# [0.04156459673907739, 35, 63, 1.0, 0.771949336010339, 0.7749628878335563, 0.8500152348533742, 17, 0.05339436039286057, 10]
#
# Iteration No: 61 ended. Search finished for the next optimal point.
# Time taken: 2.4043
# Function value obtained: 0.1468
# Current minimum: 0.1403
# Iteration No: 62 started. Searching for the next optimal point.
# [0.04441640237268531, 52, 49, 0.9533279936558161, 0.32317447814997036, 0.8038806606106279, 1.0, 17, 0.08155903456413556, 14]
#
# Iteration No: 62 ended. Search finished for the next optimal point.
# Time taken: 2.9213
# Function value obtained: 0.1437
# Current minimum: 0.1403
# Iteration No: 63 started. Searching for the next optimal point.
# [0.052696683710173914, 2, 69, 0.9625737562610457, 0.1, 0.9, 0.8822537419800578, 17, 0.06537088315980835, 25]
#
# Iteration No: 63 ended. Search finished for the next optimal point.
# Time taken: 1.9694
# Function value obtained: 0.2741
# Current minimum: 0.1403
# Iteration No: 64 started. Searching for the next optimal point.
# [0.03900406510667439, 22, 1, 0.5284907846684663, 0.24016634661632352, 0.7710362730635448, 0.8852970171296793, 21, 0.1, 10]
#
# Iteration No: 64 ended. Search finished for the next optimal point.
# Time taken: 2.4351
# Function value obtained: 0.1437
# Current minimum: 0.1403
# Iteration No: 65 started. Searching for the next optimal point.
# [0.03776975435269617, 88, 1, 1.0, 0.43035451791435697, 0.7087272799930963, 0.8, 17, 0.08615778771895567, 25]
#
# Iteration No: 65 ended. Search finished for the next optimal point.
# Time taken: 3.1333
# Function value obtained: 0.1432
# Current minimum: 0.1403
# Iteration No: 66 started. Searching for the next optimal point.
# [0.001, 2, 1, 1.0, 1.0, 0.1, 1.0, 19, 0.1, 10]
#
# Iteration No: 66 ended. Search finished for the next optimal point.
# Time taken: 1.9795
# Function value obtained: 1.0056
# Current minimum: 0.1403
# Iteration No: 67 started. Searching for the next optimal point.
# [0.05225650434174648, 28, 1, 1.0, 1.0, 0.9, 0.9849469958690136, 25, 0.0751478530675515, 10]
#
# Iteration No: 67 ended. Search finished for the next optimal point.
# Time taken: 2.6988
# Function value obtained: 0.1403
# Current minimum: 0.1403
# Iteration No: 68 started. Searching for the next optimal point.
# [0.1, 30, 1, 0.15243828532556655, 1.0, 0.9, 1.0, 25, 0.001, 10]
#
# Iteration No: 68 ended. Search finished for the next optimal point.
# Time taken: 2.8672
# Function value obtained: 0.1423
# Current minimum: 0.1403
# Iteration No: 69 started. Searching for the next optimal point.
# [0.04382737793920014, 40, 1, 0.10755155223068437, 0.35130517450931065, 0.8315864179348783, 0.9866854028897962, 20, 0.06167328001428598, 10]
#
# Iteration No: 69 ended. Search finished for the next optimal point.
# Time taken: 2.9525
# Function value obtained: 0.1427
# Current minimum: 0.1403
# Iteration No: 70 started. Searching for the next optimal point.
# [0.1, 72, 1, 1.0, 0.1, 0.45813095407533233, 0.8, 17, 0.1, 25]
#
# Iteration No: 70 ended. Search finished for the next optimal point.
# Time taken: 2.5965
# Function value obtained: 0.1981
# Current minimum: 0.1403
# Iteration No: 71 started. Searching for the next optimal point.
# [0.046736026252535326, 26, 1, 0.9525604729464158, 1.0, 0.9, 0.9070254412384031, 24, 0.001, 10]
#
# Iteration No: 71 ended. Search finished for the next optimal point.
# Time taken: 2.7252
# Function value obtained: 0.1410
# Current minimum: 0.1403
# Iteration No: 72 started. Searching for the next optimal point.
# [0.04282236070559236, 62, 81, 1.0, 0.1, 0.9, 0.958302369995029, 21, 0.010654561652060843, 10]
#
# Iteration No: 72 ended. Search finished for the next optimal point.
# Time taken: 2.6001
# Function value obtained: 0.1486
# Current minimum: 0.1403
# Iteration No: 73 started. Searching for the next optimal point.
# [0.04541339478892731, 16, 1, 0.05, 1.0, 0.7826295475419419, 0.8843409058106642, 22, 0.06630536689446012, 10]
#
# Iteration No: 73 ended. Search finished for the next optimal point.
# Time taken: 2.8816
# Function value obtained: 0.1426
# Current minimum: 0.1403
# Iteration No: 74 started. Searching for the next optimal point.
# [0.03787546598484376, 74, 1, 1.0, 0.9562896303752331, 0.8723551370265209, 0.914695066462717, 18, 0.07675439591081594, 24]
#
# Iteration No: 74 ended. Search finished for the next optimal point.
# Time taken: 3.6692
# Function value obtained: 0.1434
# Current minimum: 0.1403
# Iteration No: 75 started. Searching for the next optimal point.
# [0.1, 22, 1, 0.15074301101312837, 0.8020190204834396, 0.9, 0.9684919272552563, 21, 0.034963384786544885, 10]
#
# Iteration No: 75 ended. Search finished for the next optimal point.
# Time taken: 2.7423
# Function value obtained: 0.1409
# Current minimum: 0.1403
# Iteration No: 76 started. Searching for the next optimal point.
# [0.032381565351165834, 84, 1, 1.0, 0.26611812378064237, 0.8068345288125941, 0.8, 17, 0.1, 19]
#
# Iteration No: 76 ended. Search finished for the next optimal point.
# Time taken: 3.6744
# Function value obtained: 0.1461
# Current minimum: 0.1403
# Iteration No: 77 started. Searching for the next optimal point.
# [0.1, 91, 1, 1.0, 0.1, 0.1, 1.0, 25, 0.05362590888035363, 10]
#
# Iteration No: 77 ended. Search finished for the next optimal point.
# Time taken: 3.3219
# Function value obtained: 0.2106
# Current minimum: 0.1403
# Iteration No: 78 started. Searching for the next optimal point.
# [0.1, 100, 1, 1.0, 0.9122971307438887, 0.9, 0.8, 17, 0.1, 25]
#
# Iteration No: 78 ended. Search finished for the next optimal point.
# Time taken: 3.1615
# Function value obtained: 0.1421
# Current minimum: 0.1403
# Iteration No: 79 started. Searching for the next optimal point.
# [0.0427262138353877, 114, 1, 0.48503938100636734, 0.1, 0.6806017679113957, 0.8, 17, 0.1, 25]
#
# Iteration No: 79 ended. Search finished for the next optimal point.
# Time taken: 3.5535
# Function value obtained: 0.1418
# Current minimum: 0.1403
# Iteration No: 80 started. Searching for the next optimal point.
# [0.04303536989353772, 29, 1, 1.0, 0.16203005614444452, 0.7137921251285027, 1.0, 20, 0.1, 10]
#
# Iteration No: 80 ended. Search finished for the next optimal point.
# Time taken: 3.0272
# Function value obtained: 0.1416
# Current minimum: 0.1403
# Iteration No: 81 started. Searching for the next optimal point.
# [0.1, 74, 1, 0.3641326759935, 1.0, 0.9, 0.8, 22, 0.1, 25]
#
# Iteration No: 81 ended. Search finished for the next optimal point.
# Time taken: 3.1331
# Function value obtained: 0.1422
# Current minimum: 0.1403
# Iteration No: 82 started. Searching for the next optimal point.
# [0.1, 59, 1, 1.0, 0.1, 0.9, 0.8, 17, 0.1, 10]
#
# Iteration No: 82 ended. Search finished for the next optimal point.
# Time taken: 3.3845
# Function value obtained: 0.1430
# Current minimum: 0.1403
# Iteration No: 83 started. Searching for the next optimal point.
# [0.05924976941534353, 63, 100, 0.6520620819414479, 0.1, 0.1, 0.9852188395305949, 17, 0.1, 18]
#
# Iteration No: 83 ended. Search finished for the next optimal point.
# Time taken: 2.6098
# Function value obtained: 0.2032
# Current minimum: 0.1403
# Iteration No: 84 started. Searching for the next optimal point.
# [0.1, 128, 1, 1.0, 1.0, 0.1, 1.0, 17, 0.1, 25]
#
# Iteration No: 84 ended. Search finished for the next optimal point.
# Time taken: 2.8681
# Function value obtained: 0.1989
# Current minimum: 0.1403
# Iteration No: 85 started. Searching for the next optimal point.
# [0.1, 93, 1, 0.48960382498462346, 0.1, 0.9, 0.8, 22, 0.1, 25]
#
# Iteration No: 85 ended. Search finished for the next optimal point.
# Time taken: 3.0585
# Function value obtained: 0.1422
# Current minimum: 0.1403
# Iteration No: 86 started. Searching for the next optimal point.
# [0.04092082642698992, 18, 1, 0.5660194690405824, 1.0, 0.713146075166359, 0.8281834232388269, 25, 0.001, 20]
#
# Iteration No: 86 ended. Search finished for the next optimal point.
# Time taken: 2.8524
# Function value obtained: 0.1442
# Current minimum: 0.1403
# Iteration No: 87 started. Searching for the next optimal point.
# [0.1, 100, 99, 1.0, 0.1, 0.9, 0.8, 17, 0.1, 25]
#
# Iteration No: 87 ended. Search finished for the next optimal point.
# Time taken: 2.6504
# Function value obtained: 0.1486
# Current minimum: 0.1403
# Iteration No: 88 started. Searching for the next optimal point.
# [0.04011869612648735, 91, 1, 1.0, 0.4778816078914262, 0.5652122056125252, 0.9162117751646629, 21, 0.1, 25]
#
# Iteration No: 88 ended. Search finished for the next optimal point.
# Time taken: 3.3790
# Function value obtained: 0.2251
# Current minimum: 0.1403
# Iteration No: 89 started. Searching for the next optimal point.
# [0.1, 47, 1, 0.6833818831042957, 0.1, 0.2695668350333311, 0.8484107998350229, 17, 0.1, 11]
#
# Iteration No: 89 ended. Search finished for the next optimal point.
# Time taken: 3.1670
# Function value obtained: 0.2028
# Current minimum: 0.1403
# Iteration No: 90 started. Searching for the next optimal point.
# [0.05300698520939126, 67, 1, 0.05, 0.21614012148747125, 0.8080480081246055, 1.0, 17, 0.1, 14]
#
# Iteration No: 90 ended. Search finished for the next optimal point.
# Time taken: 3.9080
# Function value obtained: 0.1433
# Current minimum: 0.1403
# Iteration No: 91 started. Searching for the next optimal point.
# [0.04645010794057407, 116, 1, 1.0, 0.32570647268277725, 0.7473846028641108, 0.8, 17, 0.03415541450165301, 25]
#
# Iteration No: 91 ended. Search finished for the next optimal point.
# Time taken: 4.2158
# Function value obtained: 0.1417
# Current minimum: 0.1403
# Iteration No: 92 started. Searching for the next optimal point.
# [0.1, 53, 1, 0.45692737239638037, 0.23543130303244528, 0.6932822374494034, 0.8, 17, 0.1, 23]
#
# Iteration No: 92 ended. Search finished for the next optimal point.
# Time taken: 3.3797
# Function value obtained: 0.1416
# Current minimum: 0.1403
# Iteration No: 93 started. Searching for the next optimal point.
# [0.05907893287650892, 49, 1, 0.05, 0.5013679899323482, 0.7240918384490035, 0.8012836553019693, 17, 0.1, 21]
#
# Iteration No: 93 ended. Search finished for the next optimal point.
# Time taken: 3.6270
# Function value obtained: 0.1408
# Current minimum: 0.1403
# Iteration No: 94 started. Searching for the next optimal point.
# [0.1, 56, 1, 0.45932120896212253, 0.46002413352457716, 0.7701453831786086, 0.8, 17, 0.001, 25]
#
# Iteration No: 94 ended. Search finished for the next optimal point.
# Time taken: 3.9636
# Function value obtained: 0.1443
# Current minimum: 0.1403
# Iteration No: 95 started. Searching for the next optimal point.
# [0.1, 68, 1, 1.0, 0.6384478673718396, 0.7079410234034451, 0.8699830820835814, 18, 0.1, 14]
#
# Iteration No: 95 ended. Search finished for the next optimal point.
# Time taken: 3.4606
# Function value obtained: 0.1439
# Current minimum: 0.1403
# Iteration No: 96 started. Searching for the next optimal point.
# [0.03535278486018648, 47, 1, 0.7497910395221326, 1.0, 0.9, 1.0, 25, 0.1, 25]
#
# Iteration No: 96 ended. Search finished for the next optimal point.
# Time taken: 3.8187
# Function value obtained: 0.1449
# Current minimum: 0.1403
# Iteration No: 97 started. Searching for the next optimal point.
# [0.055435066278712065, 18, 1, 1.0, 0.1, 0.7512657612665595, 1.0, 17, 0.06600191214902215, 25]
#
# Iteration No: 97 ended. Search finished for the next optimal point.
# Time taken: 3.2176
# Function value obtained: 0.1410
# Current minimum: 0.1403
# Iteration No: 98 started. Searching for the next optimal point.
# [0.1, 89, 1, 1.0, 0.1, 0.8002901408827972, 0.8, 17, 0.1, 25]
#
# Iteration No: 98 ended. Search finished for the next optimal point.
# Time taken: 3.3757
# Function value obtained: 0.1421
# Current minimum: 0.1403
# Iteration No: 99 started. Searching for the next optimal point.
# [0.06913474161146632, 20, 1, 0.05, 1.0, 0.9, 0.8381001290806455, 21, 0.049013131817535235, 25]
#
# Iteration No: 99 ended. Search finished for the next optimal point.
# Time taken: 3.4817
# Function value obtained: 0.1404
# Current minimum: 0.1403
# Iteration No: 100 started. Searching for the next optimal point.
# [0.058185027664279465, 49, 1, 1.0, 1.0, 0.9, 1.0, 25, 0.001, 21]
#
# Iteration No: 100 ended. Search finished for the next optimal point.
# Time taken: 3.9924
# Function value obtained: 0.1427
# Current minimum: 0.1403
# Iteration No: 101 started. Searching for the next optimal point.
# [0.07000961737643814, 56, 1, 1.0, 0.1, 0.6859861967518655, 0.9796079337562751, 25, 0.037095009525107796, 12]
#
# Iteration No: 101 ended. Search finished for the next optimal point.
# Time taken: 4.0999
# Function value obtained: 0.1439
# Current minimum: 0.1403
# Iteration No: 102 started. Searching for the next optimal point.
# [0.1, 32, 1, 1.0, 0.1, 0.1, 1.0, 18, 0.1, 21]
#
# Iteration No: 102 ended. Search finished for the next optimal point.
# Time taken: 3.2093
# Function value obtained: 0.1954
# Current minimum: 0.1403
# Iteration No: 103 started. Searching for the next optimal point.
# [0.052333806615419184, 22, 1, 0.9189651810372649, 0.4933071499905447, 0.7436435077861762, 0.9679356137775518, 24, 0.005616715206037843, 10]
#
# Iteration No: 103 ended. Search finished for the next optimal point.
# Time taken: 3.2897
# Function value obtained: 0.1406
# Current minimum: 0.1403
# Iteration No: 104 started. Searching for the next optimal point.
# [0.05586598880744473, 94, 1, 1.0, 0.6734087256026284, 0.9, 0.8, 20, 0.1, 25]
#
# Iteration No: 104 ended. Search finished for the next optimal point.
# Time taken: 4.0702
# Function value obtained: 0.1406
# Current minimum: 0.1403
# Iteration No: 105 started. Searching for the next optimal point.
# [0.05634795829288673, 87, 1, 1.0, 0.7402931451984952, 0.8035995856050627, 1.0, 17, 0.06486668347006605, 25]
#
# Iteration No: 105 ended. Search finished for the next optimal point.
# Time taken: 4.3009
# Function value obtained: 0.1424
# Current minimum: 0.1403
# Iteration No: 106 started. Searching for the next optimal point.
# [0.1, 17, 1, 1.0, 0.9670864582015878, 0.8138352269574195, 0.8, 24, 0.001, 20]
#
# Iteration No: 106 ended. Search finished for the next optimal point.
# Time taken: 3.2981
# Function value obtained: 0.1407
# Current minimum: 0.1403
# Iteration No: 107 started. Searching for the next optimal point.
# [0.1, 41, 1, 1.0, 0.8933867489038556, 0.7346587938839962, 0.8, 20, 0.1, 10]
#
# Iteration No: 107 ended. Search finished for the next optimal point.
# Time taken: 3.5680
# Function value obtained: 0.1424
# Current minimum: 0.1403
# Iteration No: 108 started. Searching for the next optimal point.
# [0.1, 45, 1, 1.0, 0.5714132047806706, 0.6114699316042235, 0.8, 17, 0.1, 11]
#
# Iteration No: 108 ended. Search finished for the next optimal point.
# Time taken: 3.8286
# Function value obtained: 0.2020
# Current minimum: 0.1403
# Iteration No: 109 started. Searching for the next optimal point.
# [0.1, 112, 1, 1.0, 0.1, 0.8226411017516193, 0.8, 25, 0.1, 25]
#
# Iteration No: 109 ended. Search finished for the next optimal point.
# Time taken: 3.9732
# Function value obtained: 0.1422
# Current minimum: 0.1403
# Iteration No: 110 started. Searching for the next optimal point.
# [0.1, 87, 1, 1.0, 0.23674146408322835, 0.29005424156466864, 0.9026573224823377, 25, 0.1, 12]
#
# Iteration No: 110 ended. Search finished for the next optimal point.
# Time taken: 3.9751
# Function value obtained: 0.2047
# Current minimum: 0.1403
# Iteration No: 111 started. Searching for the next optimal point.
# [0.1, 97, 1, 1.0, 0.1, 0.7191542189526028, 0.9333747096089487, 25, 0.08716643903610703, 25]
#
# Iteration No: 111 ended. Search finished for the next optimal point.
# Time taken: 4.0643
# Function value obtained: 0.1422
# Current minimum: 0.1403
# Iteration No: 112 started. Searching for the next optimal point.
# [0.0681315228812541, 46, 1, 1.0, 0.789946537815337, 0.7583074574982089, 1.0, 25, 0.1, 25]
#
# Iteration No: 112 ended. Search finished for the next optimal point.
# Time taken: 4.0362
# Function value obtained: 0.1424
# Current minimum: 0.1403
# Iteration No: 113 started. Searching for the next optimal point.
# [0.06174892593849112, 38, 1, 0.10002629915802465, 0.1, 0.7576163924743069, 0.872433964743896, 22, 0.055450646950761476, 12]
#
# Iteration No: 113 ended. Search finished for the next optimal point.
# Time taken: 4.1299
# Function value obtained: 0.1409
# Current minimum: 0.1403
# Iteration No: 114 started. Searching for the next optimal point.
# [0.028683216052527216, 98, 1, 1.0, 0.11650122543271296, 0.9, 0.8, 17, 0.1, 22]
#
# Iteration No: 114 ended. Search finished for the next optimal point.
# Time taken: 4.7276
# Function value obtained: 0.1508
# Current minimum: 0.1403
# Iteration No: 115 started. Searching for the next optimal point.
# [0.1, 2, 1, 0.05, 1.0, 0.7421562849855805, 1.0, 17, 0.055101129128912414, 25]
#
# Iteration No: 115 ended. Search finished for the next optimal point.
# Time taken: 3.3640
# Function value obtained: 0.2239
# Current minimum: 0.1403
# Iteration No: 116 started. Searching for the next optimal point.
# [0.05975134062061591, 100, 1, 1.0, 0.1, 0.7551792624093829, 0.8, 25, 0.1, 11]
#
# Iteration No: 116 ended. Search finished for the next optimal point.
# Time taken: 4.6424
# Function value obtained: 0.1435
# Current minimum: 0.1403
# Iteration No: 117 started. Searching for the next optimal point.
# [0.06590417701633285, 79, 1, 0.29981329393133854, 0.1, 0.7316942291395642, 0.8, 25, 0.1, 23]
#
# Iteration No: 117 ended. Search finished for the next optimal point.
# Time taken: 4.3419
# Function value obtained: 0.1406
# Current minimum: 0.1403
# Iteration No: 118 started. Searching for the next optimal point.
# [0.1, 29, 1, 0.2120719526626073, 0.1, 0.813123340177288, 0.901472394619098, 25, 0.1, 25]
#
# Iteration No: 118 ended. Search finished for the next optimal point.
# Time taken: 3.8547
# Function value obtained: 0.1415
# Current minimum: 0.1403
# Iteration No: 119 started. Searching for the next optimal point.
# [0.1, 56, 100, 1.0, 0.1, 0.7217696058774793, 0.8, 23, 0.1, 10]
#
# Iteration No: 119 ended. Search finished for the next optimal point.
# Time taken: 4.0435
# Function value obtained: 0.1478
# Current minimum: 0.1403
# Iteration No: 120 started. Searching for the next optimal point.
# [0.1, 116, 1, 1.0, 0.1, 0.9, 0.8, 17, 0.1, 25]
#
# Iteration No: 120 ended. Search finished for the next optimal point.
# Time taken: 4.2711
# Function value obtained: 0.1421
# Current minimum: 0.1403
# Iteration No: 121 started. Searching for the next optimal point.
# [0.07899725321175799, 19, 1, 1.0, 0.6422310663019418, 0.8639727673086439, 0.8, 25, 0.09640426904275723, 10]
#
# Iteration No: 121 ended. Search finished for the next optimal point.
# Time taken: 4.0997
# Function value obtained: 0.1405
# Current minimum: 0.1403
# Iteration No: 122 started. Searching for the next optimal point.
# [0.1, 83, 1, 0.05, 0.1, 0.6853718920785744, 0.999457069887749, 24, 0.001, 25]
#
# Iteration No: 122 ended. Search finished for the next optimal point.
# Time taken: 5.0761
# Function value obtained: 0.1476
# Current minimum: 0.1403
# Iteration No: 123 started. Searching for the next optimal point.
# [0.04474597922087658, 45, 1, 1.0, 0.39778672690420147, 0.7507693543449778, 0.9488107063739069, 25, 0.001, 25]
#
# Iteration No: 123 ended. Search finished for the next optimal point.
# Time taken: 4.7006
# Function value obtained: 0.1415
# Current minimum: 0.1403
# Iteration No: 124 started. Searching for the next optimal point.
# [0.1, 128, 1, 1.0, 0.24949370636473991, 0.829000937480958, 0.8, 19, 0.1, 23]
#
# Iteration No: 124 ended. Search finished for the next optimal point.
# Time taken: 4.3869
# Function value obtained: 0.1412
# Current minimum: 0.1403
# Iteration No: 125 started. Searching for the next optimal point.
# [0.04107038923419853, 84, 1, 0.4014627106431842, 0.1, 0.9, 1.0, 25, 0.014179787823030997, 25]
#
# Iteration No: 125 ended. Search finished for the next optimal point.
# Time taken: 5.4617
# Function value obtained: 0.1441
# Current minimum: 0.1403
# Iteration No: 126 started. Searching for the next optimal point.
# [0.1, 2, 1, 0.8842432108568067, 0.1, 0.2565951557551107, 1.0, 18, 0.1, 11]
#
# Iteration No: 126 ended. Search finished for the next optimal point.
# Time taken: 3.7327
# Function value obtained: 0.2217
# Current minimum: 0.1403
# Iteration No: 127 started. Searching for the next optimal point.
# [0.04615344127437249, 110, 1, 1.0, 0.1, 0.9, 0.8, 25, 0.1, 25]
#
# Iteration No: 127 ended. Search finished for the next optimal point.
# Time taken: 4.6996
# Function value obtained: 0.1413
# Current minimum: 0.1403
# Iteration No: 128 started. Searching for the next optimal point.
# [0.1, 112, 1, 1.0, 0.1, 0.7439542089355066, 0.8550471815068865, 17, 0.1, 25]
#
# Iteration No: 128 ended. Search finished for the next optimal point.
# Time taken: 4.4436
# Function value obtained: 0.1418
# Current minimum: 0.1403
# Iteration No: 129 started. Searching for the next optimal point.
# [0.061995034676625614, 62, 1, 1.0, 0.9903867901241309, 0.7372039616026468, 0.8, 17, 0.001, 24]
#
# Iteration No: 129 ended. Search finished for the next optimal point.
# Time taken: 4.9464
# Function value obtained: 0.1407
# Current minimum: 0.1403
# Iteration No: 130 started. Searching for the next optimal point.
# [0.041701212203177705, 38, 1, 0.9243258141965887, 0.19343304193553912, 0.2429299498287937, 1.0, 19, 0.1, 11]
#
# Iteration No: 130 ended. Search finished for the next optimal point.
# Time taken: 4.4964
# Function value obtained: 0.2228
# Current minimum: 0.1403
# Iteration No: 131 started. Searching for the next optimal point.
# [0.029784528245088045, 128, 1, 1.0, 0.1, 0.6631525336281854, 1.0, 19, 0.1, 25]
#
# Iteration No: 131 ended. Search finished for the next optimal point.
# Time taken: 5.1804
# Function value obtained: 0.2516
# Current minimum: 0.1403
# Iteration No: 132 started. Searching for the next optimal point.
# [0.045642772510606125, 114, 1, 0.23873006222106685, 0.1234308723541505, 0.6839722152500276, 0.8, 17, 0.001, 23]
#
# Iteration No: 132 ended. Search finished for the next optimal point.
# Time taken: 5.3994
# Function value obtained: 0.1421
# Current minimum: 0.1403
# Iteration No: 133 started. Searching for the next optimal point.
# [0.05168183963916284, 124, 1, 0.05, 0.9465735681876448, 0.7096702138943133, 0.8, 18, 0.001, 10]
#
# Iteration No: 133 ended. Search finished for the next optimal point.
# Time taken: 7.1946
# Function value obtained: 0.1478
# Current minimum: 0.1403
# Iteration No: 134 started. Searching for the next optimal point.
# [0.04526249849078429, 23, 1, 0.9454889884763136, 0.7823219348426164, 0.7486636212981488, 0.8, 25, 0.06054351057510879, 25]
#
# Iteration No: 134 ended. Search finished for the next optimal point.
# Time taken: 5.4215
# Function value obtained: 0.1421
# Current minimum: 0.1403
# Iteration No: 135 started. Searching for the next optimal point.
# [0.1, 80, 1, 1.0, 0.1, 0.9, 0.8, 17, 0.001, 25]
#
# Iteration No: 135 ended. Search finished for the next optimal point.
# Time taken: 6.2709
# Function value obtained: 0.1452
# Current minimum: 0.1403
# Iteration No: 136 started. Searching for the next optimal point.
# [0.04901388555135854, 111, 1, 0.5907507802264049, 0.419641742476936, 0.7371536327160771, 1.0, 17, 0.1, 16]
#
# Iteration No: 136 ended. Search finished for the next optimal point.
# Time taken: 6.3136
# Function value obtained: 0.1451
# Current minimum: 0.1403
# Iteration No: 137 started. Searching for the next optimal point.
# [0.03242350042530698, 37, 1, 0.05, 0.5719446036432277, 0.9, 0.8, 23, 0.001, 10]
#
# Iteration No: 137 ended. Search finished for the next optimal point.
# Time taken: 5.0746
# Function value obtained: 0.1459
# Current minimum: 0.1403
# Iteration No: 138 started. Searching for the next optimal point.
# [0.03431985718231919, 85, 1, 0.8715540814555577, 0.1, 0.729294809178835, 0.8, 17, 0.001, 13]
#
# Iteration No: 138 ended. Search finished for the next optimal point.
# Time taken: 6.1841
# Function value obtained: 0.1461
# Current minimum: 0.1403
# Iteration No: 139 started. Searching for the next optimal point.
# [0.07445013621405105, 20, 1, 0.05, 0.93721976329273, 0.9, 0.8, 25, 0.001, 10]
#
# Iteration No: 139 ended. Search finished for the next optimal point.
# Time taken: 4.5869
# Function value obtained: 0.1399
# Current minimum: 0.1399
# Iteration No: 140 started. Searching for the next optimal point.
# [0.1, 95, 1, 0.570598823092803, 0.1, 0.47781031336240476, 0.8, 18, 0.001, 25]
#
# Iteration No: 140 ended. Search finished for the next optimal point.
# Time taken: 5.5955
# Function value obtained: 0.1999
# Current minimum: 0.1399
# Iteration No: 141 started. Searching for the next optimal point.
# [0.06938919511777455, 55, 7, 0.34064418085427445, 0.31309202474011966, 0.1722062381688077, 0.9795173794298614, 22, 0.001, 21]
#
# Iteration No: 141 ended. Search finished for the next optimal point.
# Time taken: 6.5368
# Function value obtained: 0.2072
# Current minimum: 0.1399
# Iteration No: 142 started. Searching for the next optimal point.
# [0.041888373195983895, 20, 1, 1.0, 0.5602024787111685, 0.7904392773749561, 1.0, 23, 0.001, 10]
#
# Iteration No: 142 ended. Search finished for the next optimal point.
# Time taken: 5.3741
# Function value obtained: 0.1434
# Current minimum: 0.1399
# Iteration No: 143 started. Searching for the next optimal point.
# [0.039987908896772506, 128, 1, 0.9617875912368634, 0.7772672438196224, 0.8123287878498133, 0.9756740060393411, 17, 0.001, 25]
#
# Iteration No: 143 ended. Search finished for the next optimal point.
# Time taken: 6.8541
# Function value obtained: 0.1440
# Current minimum: 0.1399
# Iteration No: 144 started. Searching for the next optimal point.
# [0.03333935587821444, 41, 100, 0.5979846545409414, 1.0, 0.8840048358035173, 0.8, 21, 0.001, 13]
#
# Iteration No: 144 ended. Search finished for the next optimal point.
# Time taken: 5.1351
# Function value obtained: 0.1617
# Current minimum: 0.1399
# Iteration No: 145 started. Searching for the next optimal point.
# [0.052083561804299586, 86, 1, 0.6646469743789339, 0.1, 0.3476052632940032, 0.8, 17, 0.001, 20]
#
# Iteration No: 145 ended. Search finished for the next optimal point.
# Time taken: 5.9787
# Function value obtained: 0.2145
# Current minimum: 0.1399
# Iteration No: 146 started. Searching for the next optimal point.
# [0.05390479353493108, 128, 1, 0.05, 0.1, 0.7125217124435402, 0.8, 21, 0.1, 10]
#
# Iteration No: 146 ended. Search finished for the next optimal point.
# Time taken: 5.9610
# Function value obtained: 0.1440
# Current minimum: 0.1399
# Iteration No: 147 started. Searching for the next optimal point.
# [0.02951368310814708, 68, 1, 0.8322856147070166, 0.8937741583658866, 0.736828962196019, 0.8341211302076208, 17, 0.08298047897664985, 10]
#
# Iteration No: 147 ended. Search finished for the next optimal point.
# Time taken: 6.2567
# Function value obtained: 0.1499
# Current minimum: 0.1399
# Iteration No: 148 started. Searching for the next optimal point.
# [0.09986604459407995, 23, 1, 1.0, 1.0, 0.8493249033405625, 0.8, 17, 0.07205037243267247, 15]
#
# Iteration No: 148 ended. Search finished for the next optimal point.
# Time taken: 5.5025
# Function value obtained: 0.1414
# Current minimum: 0.1399
# Iteration No: 149 started. Searching for the next optimal point.
# [0.1, 98, 1, 1.0, 1.0, 0.7839626772984055, 0.8, 25, 0.08371391852246761, 25]
#
# Iteration No: 149 ended. Search finished for the next optimal point.
# Time taken: 5.7620
# Function value obtained: 0.1417
# Current minimum: 0.1399
# Iteration No: 150 started. Searching for the next optimal point.
# [0.06961335656500153, 97, 1, 0.8607481049028188, 0.1, 0.7012484135449238, 0.8, 17, 0.1, 25]
#
# Iteration No: 150 ended. Search finished for the next optimal point.
# Time taken: 5.8227
# Function value obtained: 0.1409
# Current minimum: 0.1399
# Iteration No: 151 started. Searching for the next optimal point.
# [0.04922898979513796, 120, 100, 0.6086848576340805, 0.6315842890347716, 0.1, 0.8, 25, 0.07472279692255608, 24]
#
# Iteration No: 151 ended. Search finished for the next optimal point.
# Time taken: 5.4675
# Function value obtained: 0.2095
# Current minimum: 0.1399
# Iteration No: 152 started. Searching for the next optimal point.
# [0.07724932541576811, 18, 1, 0.3956951620619695, 0.1, 0.8469817925760118, 1.0, 25, 0.001, 10]
#
# Iteration No: 152 ended. Search finished for the next optimal point.
# Time taken: 5.5679
# Function value obtained: 0.1412
# Current minimum: 0.1399
# Iteration No: 153 started. Searching for the next optimal point.
# [0.06783593221405335, 22, 1, 0.30367351593460556, 1.0, 0.795613157374314, 1.0, 17, 0.00441005606132442, 25]
#
# Iteration No: 153 ended. Search finished for the next optimal point.
# Time taken: 4.9366
# Function value obtained: 0.1401
# Current minimum: 0.1399
# Iteration No: 154 started. Searching for the next optimal point.
# [0.027135534436446913, 2, 1, 0.05, 0.1, 0.3572504672552548, 0.9276245632563663, 18, 0.09196749578461141, 16]
#
# Iteration No: 154 ended. Search finished for the next optimal point.
# Time taken: 4.8913
# Function value obtained: 0.4434
# Current minimum: 0.1399
# Iteration No: 155 started. Searching for the next optimal point.
# [0.03673119222459203, 114, 1, 0.6606433894390353, 0.9806500903474129, 0.7384707465219618, 0.838125527572032, 17, 0.07143853654420945, 25]
#
# Iteration No: 155 ended. Search finished for the next optimal point.
# Time taken: 6.3680
# Function value obtained: 0.1437
# Current minimum: 0.1399
# Iteration No: 156 started. Searching for the next optimal point.
# [0.05505159494567075, 71, 1, 0.05, 0.1, 0.6783535834868137, 0.9136844996795191, 17, 0.1, 20]
#
# Iteration No: 156 ended. Search finished for the next optimal point.
# Time taken: 6.1908
# Function value obtained: 0.1421
# Current minimum: 0.1399
# Iteration No: 157 started. Searching for the next optimal point.
# [0.05207867317974783, 66, 1, 0.8125356917048834, 1.0, 0.9, 0.8, 17, 0.1, 25]
#
# Iteration No: 157 ended. Search finished for the next optimal point.
# Time taken: 5.8131
# Function value obtained: 0.1408
# Current minimum: 0.1399
# Iteration No: 158 started. Searching for the next optimal point.
# [0.04150294860561, 57, 1, 0.05, 0.1, 0.6822265871957497, 0.9878179497202249, 22, 0.1, 19]
#
# Iteration No: 158 ended. Search finished for the next optimal point.
# ...
#
# Iteration No: 143 ended. Search finished for the next optimal point.
# Time taken: 4.2570
# Function value obtained: 0.1663
# Current minimum: 0.1642
# Iteration No: 144 started. Searching for the next optimal point.
# [0.1, 56, 23, 0.05, 1.0, 0.1, 0.8, 17, 0.001, 25]
#
# Iteration No: 144 ended. Search finished for the next optimal point.
# Time taken: 4.8093
# Function value obtained: 0.1664
# Current minimum: 0.1642
# Iteration No: 145 started. Searching for the next optimal point.
# [0.1, 99, 27, 1.0, 1.0, 0.1, 1.0, 17, 0.003281679227109641, 18]
#
# Iteration No: 145 ended. Search finished for the next optimal point.
# Time taken: 4.5808
# Function value obtained: 0.1648
# Current minimum: 0.1642
# Iteration No: 146 started. Searching for the next optimal point.
# [0.06890056845341752, 111, 1, 0.9965285258111198, 0.1, 0.9, 1.0, 25, 0.001, 25]
#
# Iteration No: 146 ended. Search finished for the next optimal point.
# Time taken: 4.4164
# Function value obtained: 0.1689
# Current minimum: 0.1642
# Iteration No: 147 started. Searching for the next optimal point.
# [0.1, 84, 22, 0.05, 1.0, 0.1, 1.0, 17, 0.04128575892534134, 25]
#
# Iteration No: 147 ended. Search finished for the next optimal point.
# Time taken: 4.5366
# Function value obtained: 0.1646
# Current minimum: 0.1642
# Iteration No: 148 started. Searching for the next optimal point.
# [0.1, 61, 28, 1.0, 0.1, 0.1, 1.0, 17, 0.1, 22]
#
# Iteration No: 148 ended. Search finished for the next optimal point.
# Time taken: 4.8801
# Function value obtained: 0.1659
# Current minimum: 0.1642
# Iteration No: 149 started. Searching for the next optimal point.
# [0.05691767716606607, 36, 40, 0.6947037837081453, 0.7650667432101402, 0.8197284338831634, 0.9261057588861512, 19, 0.08083376584766161, 24]
#
# Iteration No: 149 ended. Search finished for the next optimal point.
# Time taken: 4.9839
# Function value obtained: 0.1780
# Current minimum: 0.1642
# Iteration No: 150 started. Searching for the next optimal point.
# [0.1, 128, 21, 1.0, 0.1, 0.1, 1.0, 25, 0.001, 25]
#
# Iteration No: 150 ended. Search finished for the next optimal point.
# Time taken: 4.8096
# Function value obtained: 0.1652
# Current minimum: 0.1642
# Iteration No: 151 started. Searching for the next optimal point.
# [0.1, 47, 1, 0.05, 0.1, 0.1, 1.0, 17, 0.001, 25]
#
# Iteration No: 151 ended. Search finished for the next optimal point.
# Time taken: 4.8263
# Function value obtained: 0.1652
# Current minimum: 0.1642
# Iteration No: 152 started. Searching for the next optimal point.
# [0.1, 82, 1, 0.05, 0.1, 0.1, 1.0, 25, 0.001, 25]
#
# Iteration No: 152 ended. Search finished for the next optimal point.
# Time taken: 4.7629
# Function value obtained: 0.1652
# Current minimum: 0.1642
# Iteration No: 153 started. Searching for the next optimal point.
# [0.1, 103, 26, 0.05, 0.1, 0.1, 1.0, 17, 0.001, 20]
#
# Iteration No: 153 ended. Search finished for the next optimal point.
# Time taken: 4.8483
# Function value obtained: 0.1652
# Current minimum: 0.1642
# Iteration No: 154 started. Searching for the next optimal point.
# [0.1, 64, 1, 0.21166462073292225, 0.2883288405312342, 0.44680803742626074, 0.8, 23, 0.001, 25]
#
# Iteration No: 154 ended. Search finished for the next optimal point.
# Time taken: 4.9942
# Function value obtained: 0.1664
# Current minimum: 0.1642
# Iteration No: 155 started. Searching for the next optimal point.
# [0.1, 128, 20, 0.05, 1.0, 0.1, 1.0, 25, 0.001, 25]
#
# Iteration No: 155 ended. Search finished for the next optimal point.
# Time taken: 4.6055
# Function value obtained: 0.1652
# Current minimum: 0.1642
# Iteration No: 156 started. Searching for the next optimal point.
# [0.04875097137533572, 47, 31, 0.05, 0.5151622637717667, 0.9, 1.0, 17, 0.0693824415042201, 10]
#
# Iteration No: 156 ended. Search finished for the next optimal point.
# Time taken: 4.6336
# Function value obtained: 0.1712
# Current minimum: 0.1642
# Iteration No: 157 started. Searching for the next optimal point.
# [0.1, 93, 24, 0.05, 0.1, 0.1, 1.0, 17, 0.001, 20]
#
# Iteration No: 157 ended. Search finished for the next optimal point.
# Time taken: 4.7657
# Function value obtained: 0.1669
# Current minimum: 0.1642
# Iteration No: 158 started. Searching for the next optimal point.
# [0.1, 128, 27, 1.0, 1.0, 0.1, 1.0, 23, 0.001, 19]
#
# Iteration No: 158 ended. Search finished for the next optimal point.
# Time taken: 5.0183
# Function value obtained: 0.1642
# Current minimum: 0.1642
# Iteration No: 159 started. Searching for the next optimal point.
# [0.1, 82, 10, 0.7202606587758852, 0.1, 0.1, 0.8, 17, 0.001, 25]
#
# Iteration No: 159 ended. Search finished for the next optimal point.
# Time taken: 5.1980
# Function value obtained: 0.1664
# Current minimum: 0.1642
# Iteration No: 160 started. Searching for the next optimal point.
# [0.1, 50, 27, 0.05, 0.25799231261210676, 0.1, 1.0, 17, 0.001, 25]
#
# Iteration No: 160 ended. Search finished for the next optimal point.
# Time taken: 4.8807
# Function value obtained: 0.1642
# Current minimum: 0.1642
# Iteration No: 161 started. Searching for the next optimal point.
# [0.1, 45, 30, 0.05, 0.1, 0.1, 1.0, 20, 0.001, 21]
#
# Iteration No: 161 ended. Search finished for the next optimal point.
# Time taken: 5.3961
# Function value obtained: 0.1647
# Current minimum: 0.1642
# Iteration No: 162 started. Searching for the next optimal point.
# [0.1, 55, 26, 1.0, 0.1, 0.1, 1.0, 17, 0.1, 25]
#
# Iteration No: 162 ended. Search finished for the next optimal point.
# Time taken: 4.9903
# Function value obtained: 0.1664
# Current minimum: 0.1642
# Iteration No: 163 started. Searching for the next optimal point.
# [0.1, 107, 22, 1.0, 0.1, 0.1, 1.0, 17, 0.001, 25]
#
# Iteration No: 163 ended. Search finished for the next optimal point.
# Time taken: 5.2191
# Function value obtained: 0.1652
# Current minimum: 0.1642
# Iteration No: 164 started. Searching for the next optimal point.
# [0.1, 128, 27, 1.0, 1.0, 0.1, 1.0, 25, 0.001, 18]
#
# Iteration No: 164 ended. Search finished for the next optimal point.
# Time taken: 5.6958
# Function value obtained: 0.1642
# Current minimum: 0.1642
# Iteration No: 165 started. Searching for the next optimal point.
# [0.1, 128, 26, 1.0, 1.0, 0.1, 1.0, 17, 0.001, 19]
#
# Iteration No: 165 ended. Search finished for the next optimal point.
# Time taken: 5.9077
# Function value obtained: 0.1652
# Current minimum: 0.1642
# Iteration No: 166 started. Searching for the next optimal point.
# [0.1, 128, 28, 0.17240295435891745, 0.9007385743030074, 0.9, 1.0, 17, 0.001, 17]
#
# Iteration No: 166 ended. Search finished for the next optimal point.
# Time taken: 5.8797
# Function value obtained: 0.1683
# Current minimum: 0.1642
# Iteration No: 167 started. Searching for the next optimal point.
# [0.1, 128, 20, 0.05, 0.2239411272495495, 0.1, 0.8, 25, 0.001, 25]
#
# Iteration No: 167 ended. Search finished for the next optimal point.
# Time taken: 5.6992
# Function value obtained: 0.1664
# Current minimum: 0.1642
# Iteration No: 168 started. Searching for the next optimal point.
# [0.1, 128, 21, 1.0, 0.1, 0.1, 1.0, 25, 0.001, 25]
# /usr/local/lib/python3.7/dist-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Iteration No: 168 ended. Search finished for the next optimal point.
# Time taken: 5.6981
# Function value obtained: 0.1652
# Current minimum: 0.1642
# Iteration No: 169 started. Searching for the next optimal point.
# [0.1, 47, 25, 1.0, 0.8365796179212991, 0.1, 1.0, 17, 0.013554685706173141, 25]
#
# Iteration No: 169 ended. Search finished for the next optimal point.
# Time taken: 5.9210
# Function value obtained: 0.1653
# Current minimum: 0.1642
# Iteration No: 170 started. Searching for the next optimal point.
# [0.1, 84, 1, 0.05, 0.1, 0.1, 1.0, 21, 0.001, 25]
#
# Iteration No: 170 ended. Search finished for the next optimal point.
# Time taken: 6.0320
# Function value obtained: 0.1652
# Current minimum: 0.1642
# Iteration No: 171 started. Searching for the next optimal point.
# [0.1, 68, 1, 0.05, 1.0, 0.1, 0.8, 25, 0.001, 25]
#
# Iteration No: 171 ended. Search finished for the next optimal point.
# Time taken: 5.8779
# Function value obtained: 0.1664
# Current minimum: 0.1642
# Iteration No: 172 started. Searching for the next optimal point.
# [0.1, 46, 26, 0.1673403877984973, 1.0, 0.1, 0.9896326980993091, 17, 0.001, 23]
#
# Iteration No: 172 ended. Search finished for the next optimal point.
# Time taken: 5.9700
# Function value obtained: 0.1649
# Current minimum: 0.1642
# Iteration No: 173 started. Searching for the next optimal point.
# [0.1, 55, 10, 0.05, 1.0, 0.1, 1.0, 19, 0.001, 25]
#
# Iteration No: 173 ended. Search finished for the next optimal point.
# Time taken: 6.2099
# Function value obtained: 0.1652
# Current minimum: 0.1642
# Iteration No: 174 started. Searching for the next optimal point.
# [0.1, 73, 25, 1.0, 0.3635583547204073, 0.1, 1.0, 25, 0.001, 25]
#
# Iteration No: 174 ended. Search finished for the next optimal point.
# Time taken: 6.1240
# Function value obtained: 0.1652
# Current minimum: 0.1642
# Iteration No: 175 started. Searching for the next optimal point.
# [0.1, 58, 1, 0.05, 0.1, 0.9, 1.0, 25, 0.001, 25]
#
# Iteration No: 175 ended. Search finished for the next optimal point.
# Time taken: 5.7116
# Function value obtained: 0.1678
# Current minimum: 0.1642
# Iteration No: 176 started. Searching for the next optimal point.
# [0.1, 44, 29, 0.9524569371241056, 0.1, 0.1, 1.0, 21, 0.001, 20]
#
# Iteration No: 176 ended. Search finished for the next optimal point.
# Time taken: 5.9465
# Function value obtained: 0.1671
# Current minimum: 0.1642
# Iteration No: 177 started. Searching for the next optimal point.
# [0.1, 128, 25, 0.463213985757303, 0.1, 0.1, 1.0, 17, 0.001, 20]
#
# Iteration No: 177 ended. Search finished for the next optimal point.
# Time taken: 6.5479
# Function value obtained: 0.1652
# Current minimum: 0.1642
# Iteration No: 178 started. Searching for the next optimal point.
# [0.1, 128, 28, 0.05, 1.0, 0.1, 1.0, 23, 0.001, 18]
#
# Iteration No: 178 ended. Search finished for the next optimal point.
# Time taken: 6.0308
# Function value obtained: 0.1655
# Current minimum: 0.1642
# Iteration No: 179 started. Searching for the next optimal point.
# [0.1, 57, 15, 0.05, 0.1, 0.1, 1.0, 17, 0.001, 25]
#
# Iteration No: 179 ended. Search finished for the next optimal point.
# Time taken: 5.9680
# Function value obtained: 0.1652
# Current minimum: 0.1642
# Iteration No: 180 started. Searching for the next optimal point.
# [0.1, 64, 24, 1.0, 0.621259873507141, 0.1, 1.0, 17, 0.001, 21]
#
# Iteration No: 180 ended. Search finished for the next optimal point.
# Time taken: 6.0214
# Function value obtained: 0.1669
# Current minimum: 0.1642
# Iteration No: 181 started. Searching for the next optimal point.
# [0.1, 96, 14, 1.0, 0.1, 0.1, 1.0, 17, 0.001, 25]
#
# Iteration No: 181 ended. Search finished for the next optimal point.
# Time taken: 6.3126
# Function value obtained: 0.1652
# Current minimum: 0.1642
# Iteration No: 182 started. Searching for the next optimal point.
# [0.1, 59, 20, 0.11204649751718272, 0.2632678467325663, 0.1, 1.0, 25, 0.1, 25]
#
# Iteration No: 182 ended. Search finished for the next optimal point.
# Time taken: 6.1173
# Function value obtained: 0.1655
# Current minimum: 0.1642
# Iteration No: 183 started. Searching for the next optimal point.
# [0.1, 64, 1, 1.0, 0.1, 0.1, 0.8, 23, 0.001, 25]
#
# Iteration No: 183 ended. Search finished for the next optimal point.
# Time taken: 6.3053
# Function value obtained: 0.1664
# Current minimum: 0.1642
# Iteration No: 184 started. Searching for the next optimal point.
# [0.1, 94, 18, 0.05, 1.0, 0.1, 1.0, 17, 0.001, 25]
#
# Iteration No: 184 ended. Search finished for the next optimal point.
# Time taken: 6.3963
# Function value obtained: 0.1652
# Current minimum: 0.1642
# Iteration No: 185 started. Searching for the next optimal point.
# [0.1, 80, 1, 0.05, 1.0, 0.1, 1.0, 17, 0.001, 25]
#
# Iteration No: 185 ended. Search finished for the next optimal point.
# Time taken: 6.2362
# Function value obtained: 0.1652
# Current minimum: 0.1642
# Iteration No: 186 started. Searching for the next optimal point.
# [0.1, 63, 6, 0.9171297308564647, 0.923811088191096, 0.1, 1.0, 25, 0.001, 25]
#
# Iteration No: 186 ended. Search finished for the next optimal point.
# Time taken: 6.5004
# Function value obtained: 0.1652
# Current minimum: 0.1642
# Iteration No: 187 started. Searching for the next optimal point.
# [0.1, 61, 9, 0.05, 0.1, 0.1, 1.0, 17, 0.001, 25]
#
# Iteration No: 187 ended. Search finished for the next optimal point.
# Time taken: 6.6417
# Function value obtained: 0.1652
# Current minimum: 0.1642
# Iteration No: 188 started. Searching for the next optimal point.
# [0.1, 128, 29, 0.9749329991229695, 0.1, 0.1, 1.0, 25, 0.001, 15]
#
# Iteration No: 188 ended. Search finished for the next optimal point.
# Time taken: 6.5079
# Function value obtained: 0.1671
# Current minimum: 0.1642
# Iteration No: 189 started. Searching for the next optimal point.
# [0.0010016457501896942, 4, 99, 0.648368209951948, 0.2873385338248706, 0.8321604507379144, 0.8790127659152048, 18, 0.0634707022819323, 25]
#
# Iteration No: 189 ended. Search finished for the next optimal point.
# Time taken: 6.5333
# Function value obtained: 0.5233
# Current minimum: 0.1642
# Iteration No: 190 started. Searching for the next optimal point.
# [0.1, 69, 1, 0.42281102819831295, 1.0, 0.452888432735985, 0.8, 17, 0.05993198341406854, 25]
#
# Iteration No: 190 ended. Search finished for the next optimal point.
# Time taken: 7.0320
# Function value obtained: 0.1663
# Current minimum: 0.1642
# Iteration No: 191 started. Searching for the next optimal point.
# [0.1, 59, 21, 0.05, 0.728316702637307, 0.1, 1.0, 24, 0.1, 25]
#
# Iteration No: 191 ended. Search finished for the next optimal point.
# Time taken: 7.0741
# Function value obtained: 0.1655
# Current minimum: 0.1642
# Iteration No: 192 started. Searching for the next optimal point.
# [0.08248684279313737, 128, 22, 1.0, 0.14709385008888223, 0.1, 1.0, 21, 0.001, 25]
#
# Iteration No: 192 ended. Search finished for the next optimal point.
# Time taken: 7.0239
# Function value obtained: 0.1658
# Current minimum: 0.1642
# Iteration No: 193 started. Searching for the next optimal point.
# [0.1, 68, 23, 0.05, 1.0, 0.1, 1.0, 25, 0.001, 25]
#
# Iteration No: 193 ended. Search finished for the next optimal point.
# Time taken: 7.2536
# Function value obtained: 0.1652
# Current minimum: 0.1642
# Iteration No: 194 started. Searching for the next optimal point.
# [0.1, 104, 22, 0.8862284056269623, 0.1, 0.3461194112698758, 1.0, 25, 0.001, 25]
#
# Iteration No: 194 ended. Search finished for the next optimal point.
# Time taken: 7.3209
# Function value obtained: 0.1652
# Current minimum: 0.1642
# Iteration No: 195 started. Searching for the next optimal point.
# [0.040947306253096026, 128, 1, 0.22077022513015943, 0.5128295888160659, 0.9, 0.9939229633656379, 25, 0.001, 25]
#
# Iteration No: 195 ended. Search finished for the next optimal point.
# Time taken: 6.4751
# Function value obtained: 0.1714
# Current minimum: 0.1642
# Iteration No: 196 started. Searching for the next optimal point.
# [0.1, 65, 1, 0.05, 1.0, 0.1, 1.0, 17, 0.001, 25]
#
# Iteration No: 196 ended. Search finished for the next optimal point.
# Time taken: 6.2558
# Function value obtained: 0.1652
# Current minimum: 0.1642
# Iteration No: 197 started. Searching for the next optimal point.
# [0.1, 128, 25, 1.0, 0.1, 0.1, 1.0, 25, 0.001, 25]
#
# Iteration No: 197 ended. Search finished for the next optimal point.
# Time taken: 6.3428
# Function value obtained: 0.1652
# Current minimum: 0.1642
# Iteration No: 198 started. Searching for the next optimal point.
# [0.1, 75, 1, 0.7031078604145645, 0.1, 0.1, 1.0, 25, 0.1, 25]
#
# Iteration No: 198 ended. Search finished for the next optimal point.
# Time taken: 6.4878
# Function value obtained: 0.1655
# Current minimum: 0.1642
# Iteration No: 199 started. Searching for the next optimal point.
# [0.1, 97, 17, 0.05, 0.1, 0.1, 1.0, 17, 0.001, 25]
#
# Iteration No: 199 ended. Search finished for the next optimal point.
# Time taken: 6.5966
# Function value obtained: 0.1652
# Current minimum: 0.1642
# Iteration No: 200 started. Searching for the next optimal point.
# [0.1, 89, 8, 0.05, 0.1, 0.1, 1.0, 25, 0.001, 25]
#
# Iteration No: 200 ended. Search finished for the next optimal point.
# Time taken: 6.6945
# Function value obtained: 0.1652
# Current minimum: 0.1642
