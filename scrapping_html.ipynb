# %%
import pandas as pd
from tqdm import tqdm
from bs4 import BeautifulSoup
import urllib3
import requests
import os

files = os.listdir("/content/drive/MyDrive/alethea_stn/data/html_apartamentos/")
data_apartamentos = pd.DataFrame(columns = ["uf", "municipio", "endereco", "area", "metrica", "valor"])

# %%
data_apartamentos.to_csv("/content/drive/MyDrive/alethea_stn/data/html_apartamentos/", index=False)
# Out:
#         uf  ...                                              valor
# 0     RJ\n  ...  \n\n                    R$ 390.000\n          ...
# 1     RJ\n  ...  \n\n                    R$ 251.490\n          ...
# 2     RJ\n  ...  \n\n                    R$ 559.000\n          ...
# 3     RJ\n  ...  \n\n                    R$ 900.000\n          ...
# 4     RJ\n  ...  \n\n                    R$ 1.700.000\n        ...
# ...    ...  ...                                                ...
# 4722  DF\n  ...  \n\n                    R$ 720.000\n          ...
# 4723  DF\n  ...  \n\n                    R$ 860.000\n          ...
# 4724  DF\n  ...  \n\n                    R$ 1.400.000\n        ...
# 4725  DF\n  ...  \n\n                    R$ 318.000\n          ...
# 4726  DF\n  ...  \n\n                    R$ 380.000\n          ...
#
# [4727 rows x 6 columns]

# %%
errors = []

for n in range(1002, len(files)):

    with open(f'/content/drive/MyDrive/alethea_stn/data/html_apartamentos/{files[n]}', 'r') as f:
      contents = f.read()
      soup = BeautifulSoup(contents, 'lxml')

    print(f"tentando do arq {files[n]}")

    for i in tqdm(range(0, 36), desc = f"Extraindo do arq {files[n]}"):
      
      try:
        mun_res = soup.find_all(attrs={"class": "results-summary__title js-summary-title"})[0].text
        dic = {"uf": mun_res.split("em")[1].split(" - ")[1].replace(" ", ""),
                        "municipio": mun_res.split("em")[1].split(" - ")[0].replace(" ", ""),
                        "endereco": soup.find_all(attrs={"class": "property-card__content-link js-card-title"})[i].find_all(attrs={"class": "property-card__address"})[0].text, 
                        "area": soup.find_all(attrs={"class": "property-card__content-link js-card-title"})[i].find_all(attrs={"class": 'property-card__detail-value js-property-card-value property-card__detail-area js-property-card-detail-area'})[0].text, 
                        "metrica": soup.find_all(attrs={"class": "property-card__content-link js-card-title"})[i].find_all(attrs={"class": 'property-card__detail-text js-property-card-detail-text'})[0].text,
                        "valor": soup.find_all(attrs={"class": "property-card__content-link js-card-title"})[i].find_all(attrs={"class": 'property-card__price js-property-card-prices js-property-card__price-small'})[0].text
                        }
        data_apartamentos = data_apartamentos.append(dic, ignore_index = True)
      
      except:
        data_apartamentos.to_csv("/content/drive/MyDrive/alethea_stn/data/html_apartamentos/data_apartamentos.csv", index=False)
        errors.append(files[n])
        pass

data_apartamentos.to_csv("/content/drive/MyDrive/alethea_stn/data/html_apartamentos/data_apartamentos.csv", index=False)
data_apartamentos.shape
# Out:
# tentando do arq sao-paulo-sao-paulo-pagina1.html
# Extraindo do arq sao-paulo-sao-paulo-pagina1.html: 100%|██████████| 36/36 [00:08<00:00,  4.01it/s]
# tentando do arq sao-paulo-sao-paulo-pagina2.html
# Extraindo do arq sao-paulo-sao-paulo-pagina2.html: 100%|██████████| 36/36 [00:08<00:00,  4.19it/s]
# tentando do arq sao-paulo-sao-paulo-pagina3.html
# Extraindo do arq sao-paulo-sao-paulo-pagina3.html: 100%|██████████| 36/36 [00:08<00:00,  4.18it/s]
# tentando do arq sao-paulo-sao-paulo-pagina4.html
# Extraindo do arq sao-paulo-sao-paulo-pagina4.html: 100%|██████████| 36/36 [00:08<00:00,  4.15it/s]
# tentando do arq sao-paulo-sao-paulo-pagina5.html
# Extraindo do arq sao-paulo-sao-paulo-pagina5.html: 100%|██████████| 36/36 [00:08<00:00,  4.21it/s]
# tentando do arq sao-paulo-sao-paulo-pagina6.html
# Extraindo do arq sao-paulo-sao-paulo-pagina6.html: 100%|██████████| 36/36 [00:08<00:00,  4.12it/s]
# tentando do arq sao-paulo-sao-paulo-pagina7.html
# ...

# %%
# Out:
# 1001

# %%
data_apartamentos
# Out:
#          uf  ...                                              valor
# 0      RJ\n  ...  \n\n                    R$ 390.000\n          ...
# 1      RJ\n  ...  \n\n                    R$ 251.490\n          ...
# 2      RJ\n  ...  \n\n                    R$ 559.000\n          ...
# 3      RJ\n  ...  \n\n                    R$ 900.000\n          ...
# 4      RJ\n  ...  \n\n                    R$ 1.700.000\n        ...
# ...     ...  ...                                                ...
# 40566  RJ\n  ...  \n\n                    R$ 700.000\n          ...
# 40567  RJ\n  ...  \n\n                    R$ 1.500.000\n        ...
# 40568  RJ\n  ...  \n\n                    R$ 2.500.000\n        ...
# 40569  RJ\n  ...  \n\n                      R$ 3.500\n          ...
# 40570  RJ\n  ...  \n\n                    R$ 465.000\n          ...
#
# [40571 rows x 6 columns]

# %%
import googlemaps
from tqdm import tqdm 

errors = []

for i in tqdm(imoveis_residen.index):
    try:
        address = imoveis_residen["Endereço"].loc[i]
        gmaps = googlemaps.Client(key="AIzaSyCNu6xyGP8lvPP8fpSCRyOGutvl3Q8LFvE")
        result = gmaps.geocode(address)
        imoveis_residen["lat"].loc[i] = result[0]["geometry"]["location"]["lat"]
        imoveis_residen["lng"].loc[i] = result[0]["geometry"]["location"]["lng"]
        imoveis_residen["format_address"].loc[i] = result[0]["formatted_address"]
    except:
        imoveis_residen.to_csv("/Users/pbizil/Desktop/alethea_stn/data/html_residen/imoveis_residen.csv", index=False)

# %% [markdown]
# ## Casas e residencias

# %%
import pandas as pd
from tqdm import tqdm
from bs4 import BeautifulSoup
import urllib3
import requests
import os

files = os.listdir("/content/drive/MyDrive/alethea_stn/data/html_residen/")
data_residen = pd.DataFrame(columns = ["uf", "municipio", "endereco", "area", "metrica", "valor"])

# %%
errors = []

for n in range(1, len(files)):

    with open(f'/content/drive/MyDrive/alethea_stn/data/html_residen/{files[n]}', 'r') as f:
      contents = f.read()
      soup = BeautifulSoup(contents, 'lxml')

    print(f"tentando do arq {files[n]}")

    for i in tqdm(range(0, 36), desc = f"Extraindo do arq {files[n]} de n {n}"):
      
      try:
        mun_res = soup.find_all(attrs={"class": "results-summary__title js-summary-title"})[0].text
        dic = {"uf": mun_res.split("em")[1].split(" - ")[1].replace(" ", ""),
                        "municipio": mun_res.split("em")[1].split(" - ")[0].replace(" ", ""),
                        "endereco": soup.find_all(attrs={"class": "property-card__content-link js-card-title"})[i].find_all(attrs={"class": "property-card__address"})[0].text, 
                        "area": soup.find_all(attrs={"class": "property-card__content-link js-card-title"})[i].find_all(attrs={"class": 'property-card__detail-value js-property-card-value property-card__detail-area js-property-card-detail-area'})[0].text, 
                        "metrica": soup.find_all(attrs={"class": "property-card__content-link js-card-title"})[i].find_all(attrs={"class": 'property-card__detail-text js-property-card-detail-text'})[0].text,
                        "valor": soup.find_all(attrs={"class": "property-card__content-link js-card-title"})[i].find_all(attrs={"class": 'property-card__price js-property-card-prices js-property-card__price-small'})[0].text
                        }
        data_residen = data_residen.append(dic, ignore_index = True)
      
      except:
        data_residen.to_csv("/content/drive/MyDrive/alethea_stn/data/html_residen/data_residen.csv", index=False)
        errors.append(files[n])
        pass

data_residen.to_csv("/content/drive/MyDrive/alethea_stn/data/html_apartamentos/data_residen.csv", index=False)
data_residen.shape
# Out:
# tentando do arq sao-paulo-sao-paulo-pagina1.html
# Extraindo do arq sao-paulo-sao-paulo-pagina1.html de n 1: 100%|██████████| 36/36 [00:08<00:00,  4.36it/s]
# tentando do arq rio-de-janeiro-rio-de-janeiro-pagina1.html
# Extraindo do arq rio-de-janeiro-rio-de-janeiro-pagina1.html de n 2: 100%|██████████| 36/36 [00:08<00:00,  4.47it/s]
# tentando do arq distrito-federal-brasilia-pagina1.html
# Extraindo do arq distrito-federal-brasilia-pagina1.html de n 3: 100%|██████████| 36/36 [00:08<00:00,  4.37it/s]
# tentando do arq bahia-salvador-pagina1.html
# Extraindo do arq bahia-salvador-pagina1.html de n 4: 100%|██████████| 36/36 [00:08<00:00,  4.09it/s]
# tentando do arq ceara-fortaleza-pagina1.html
# Extraindo do arq ceara-fortaleza-pagina1.html de n 5: 100%|██████████| 36/36 [00:08<00:00,  4.33it/s]
# tentando do arq para-belem-pagina1.html
# Extraindo do arq para-belem-pagina1.html de n 6: 100%|██████████| 36/36 [00:08<00:00,  4.41it/s]
# ...

# %%
data_residen
# Out:
#          uf  ...                                              valor
# 0        SP  ...                                      R$ 670.000
# 1        SP  ...                                    R$ 2.400.000
# 2        SP  ...                                    R$ 1.350.000
# 3        SP  ...                                    R$ 1.300.000
# 4        SP  ...                                      R$ 370.000
# ...     ...  ...                                                ...
# 30154  MG\n  ...  \n\n                    R$ 3.700.000\n        ...
# 30155  MG\n  ...  \n\n                    R$ 600.000\n          ...
# 30156  MG\n  ...  \n\n                    R$ 890.000\n          ...
# 30157  MG\n  ...  \n\n                    R$ 1.070.000\n        ...
# 30158  MG\n  ...  \n\n                    R$ 144.000\n          ...
#
# [30159 rows x 6 columns]

# %% [markdown]
# ## Terrenos

# %%
import pandas as pd
from tqdm import tqdm
from bs4 import BeautifulSoup
import urllib3
import requests
import os

files = os.listdir("/content/drive/MyDrive/alethea_stn/data/html_terrenos")
data_terrenos = pd.DataFrame(columns = ["uf", "municipio", "endereco", "area", "metrica", "valor"])

# %%
errors = []

for n in range(1, len(files)):

    with open(f'/content/drive/MyDrive/alethea_stn/data/html_terrenos/{files[n]}', 'r') as f:
      contents = f.read()
      soup = BeautifulSoup(contents, 'lxml')

    print(f"tentando do arq {files[n]}")

    for i in tqdm(range(0, 36), desc = f"Extraindo do arq {files[n]} de n {n}"):
      
      try:
        mun_res = soup.find_all(attrs={"class": "results-summary__title js-summary-title"})[0].text
        dic = {"uf": mun_res.split("em")[1].split(" - ")[1].replace(" ", ""),
                        "municipio": mun_res.split("em")[1].split(" - ")[0].replace(" ", ""),
                        "endereco": soup.find_all(attrs={"class": "property-card__content-link js-card-title"})[i].find_all(attrs={"class": "property-card__address"})[0].text, 
                        "area": soup.find_all(attrs={"class": "property-card__content-link js-card-title"})[i].find_all(attrs={"class": 'property-card__detail-value js-property-card-value property-card__detail-area js-property-card-detail-area'})[0].text, 
                        "metrica": soup.find_all(attrs={"class": "property-card__content-link js-card-title"})[i].find_all(attrs={"class": 'property-card__detail-text js-property-card-detail-text'})[0].text,
                        "valor": soup.find_all(attrs={"class": "property-card__content-link js-card-title"})[i].find_all(attrs={"class": 'property-card__price js-property-card-prices js-property-card__price-small'})[0].text
                        }
        data_terrenos = data_residen.append(dic, ignore_index = True)
      
      except:
        data_terrenos.to_csv("/content/drive/MyDrive/alethea_stn/data/html_terrenos/data_terrenos.csv", index=False)
        errors.append(files[n])
        pass

data_terrenos.to_csv("/content/drive/MyDrive/alethea_stn/data/html_terrenos/data_terrenos.csv", index=False)
data_terrenos.shape
# Out:
# tentando do arq sao-paulo-sao-paulo-pagina1.html
# Extraindo do arq sao-paulo-sao-paulo-pagina1.html de n 1: 100%|██████████| 36/36 [00:08<00:00,  4.21it/s]
# tentando do arq sao-paulo-sao-paulo-pagina2.html
# Extraindo do arq sao-paulo-sao-paulo-pagina2.html de n 2: 100%|██████████| 36/36 [00:08<00:00,  4.44it/s]
# tentando do arq sao-paulo-sao-paulo-pagina3.html
# Extraindo do arq sao-paulo-sao-paulo-pagina3.html de n 3: 100%|██████████| 36/36 [00:07<00:00,  4.51it/s]
# tentando do arq sao-paulo-sao-paulo-pagina4.html
# Extraindo do arq sao-paulo-sao-paulo-pagina4.html de n 4: 100%|██████████| 36/36 [00:07<00:00,  4.52it/s]
# tentando do arq sao-paulo-sao-paulo-pagina5.html
# Extraindo do arq sao-paulo-sao-paulo-pagina5.html de n 5: 100%|██████████| 36/36 [00:07<00:00,  4.53it/s]
# tentando do arq sao-paulo-sao-paulo-pagina6.html
# Extraindo do arq sao-paulo-sao-paulo-pagina6.html de n 6: 100%|██████████| 36/36 [00:07<00:00,  4.55it/s]
# ...
